# %%
import pandas as pd
import gspread
from gspread_dataframe import set_with_dataframe
from oauth2client.service_account import ServiceAccountCredentials

# Auth
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('../gspread_creds.json', scope)
client = gspread.authorize(creds)

# %% [markdown]
# ### TFR-500

# %%
# Open the sheet
worksheet = client.open("tfr500_summarized").worksheet("classified")

# Get all records as list of dicts
records = worksheet.get_all_records()

# Convert to DataFrame
tfr500 = pd.DataFrame(records)

# one-hot encoding investment types # for later aggregating purpose
type_expanded = pd.get_dummies(tfr500["Type of investment"], prefix="type")
tfr500 = pd.concat([tfr500, type_expanded], axis=1)

# %%
tfr500_parent_list = tfr500.groupby('American Owner - Name').agg({
    'Name of Foreign Business': list,
    **{col: 'any' for col in type_expanded}
}).reset_index()
tfr500_parent_list = tfr500_parent_list[tfr500_parent_list['American Owner - Name']!='']
tfr500_parent_list = tfr500_parent_list.rename(columns={'American Owner - Name': 'Master US firm name',
                                                        'Name of Foreign Business': 'affiliated German firms'})
tfr500_parent_list = tfr500_parent_list[['Master US firm name']]

# %%
tfr500_parent_list.to_excel('output/trf500_parent_list.xlsx', index=False)

# %% [markdown]
# ### Moody's 1932

# %%
# Open the sheet
worksheet = client.open("Moodys 1932").worksheet("reviewed-expanded")

# Get all records as list of dicts
records = worksheet.get_all_records()

# Convert to DataFrame
moodys32 = pd.DataFrame(records)

bool_cols = ['mentions a subsidiary', 
             'mentions stock ownership',
             'subsidiary is AG',
             'subsidiary is GmbH',
             'mentions an affilated company',
             'mentions a plant/office/branch', 
             'is a subsidiary of a German firm',
             'other types of agreement']
moodys32[bool_cols] = moodys32[bool_cols].apply(lambda x: x == "TRUE")
moodys32['affiliated German firm name'] = moodys32['affiliated German firm name'].replace('NA', '')

# %%
moodys32_parent_list = moodys32.groupby("Master US firm name").agg(
    {
        "affiliated German firm name": list,
        "Master German firm name": list,
        **{col: "any" for col in bool_cols}
    }
).reset_index()

moodys32_parent_list = moodys32_parent_list[['Master US firm name']]

# %%
tfr500_moodys32 = tfr500_parent_list.merge(moodys32_parent_list, on='Master US firm name', how='outer', indicator=True)

tfr500_moodys32['TFR-500'] = tfr500_moodys32['_merge'].isin(['left_only', 'both'])
tfr500_moodys32['Moodys 32'] = tfr500_moodys32['_merge'].isin(['right_only', 'both'])

tfr500_moodys32 = tfr500_moodys32.drop(columns='_merge')

# %%
tfr500_moodys32
# Out:
#                           Master US firm name  TFR-500  Moodys 32
# 0        Addressograph-Multigraph Corporation     True       True
# 1    American -Austrian Magnesite Corporation     True      False
# 2                      American Bemberg Corp.    False       True
# 3                        American Can Company    False       True
# 4                   American Cyanamid Company     True      False
# ..                                        ...      ...        ...
# 201       Western Electric Export Corporation     True      False
# 202                      Westhold Corporation     True      False
# 203             William R. Warner & Co., Inc.     True      False
# 204                       Witroth Corporation     True      False
# 205      Worthington Pump and Machinery Corp.     True       True
#
# [206 rows x 3 columns]

# %% [markdown]
# ### Moody's 1934

# %%
# Open the sheet
worksheet = client.open("Moodys 1934").worksheet("reviewed-expanded")

# Get all records as list of dicts
records = worksheet.get_all_records()

# Convert to DataFrame
moodys34 = pd.DataFrame(records)

bool_cols = ['mentions a subsidiary', 
             'mentions stock ownership',
             'subsidiary is AG',
             'subsidiary is GmbH',
             'mentions an affilated company',
             'mentions a plant/office/branch', 
             'is a subsidiary of a German firm',
             'other types of agreement']
moodys34[bool_cols] = moodys34[bool_cols].apply(lambda x: x == "TRUE")
moodys34['affiliated German firm name'] = moodys34['affiliated German firm name'].replace('NA', '')

# %%
moodys34_parent_list = moodys34.groupby("Master US firm name").agg(
    {
        "affiliated German firm name": list,
        "Master German firm name": list,
        **{col: "any" for col in bool_cols}
    }
).reset_index()

moodys34_parent_list = moodys34_parent_list[['Master US firm name']]

# %%
tfr500_moodys32_moodys34 = tfr500_moodys32.merge(moodys34_parent_list, on='Master US firm name', how='outer', indicator=True,
                                                 suffixes=['_moodys32', '_moodys34'])

tfr500_moodys32_moodys34['TFR-500'] = tfr500_moodys32_moodys34['TFR-500'].fillna(False)
tfr500_moodys32_moodys34['Moodys 32'] = tfr500_moodys32_moodys34['Moodys 32'].fillna(False)
tfr500_moodys32_moodys34['Moodys 34'] = tfr500_moodys32_moodys34['_merge'].isin(['right_only', 'both'])

tfr500_moodys32_moodys34 = tfr500_moodys32_moodys34.drop(columns='_merge')

first_cols = ['Master US firm name', 'TFR-500', 'Moodys 32', 'Moodys 34']
other_cols = [col for col in tfr500_moodys32_moodys34.columns if col not in first_cols]

tfr500_moodys32_moodys34 = tfr500_moodys32_moodys34[first_cols + other_cols]

tfr500_moodys32_moodys34
# Out:
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_7381/2266885800.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34['TFR-500'] = tfr500_moodys32_moodys34['TFR-500'].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_7381/2266885800.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34['Moodys 32'] = tfr500_moodys32_moodys34['Moodys 32'].fillna(False)
#                           Master US firm name  TFR-500  Moodys 32  Moodys 34
# 0        Addressograph-Multigraph Corporation     True       True       True
# 1                       Alta United Mines Co.    False      False       True
# 2                 Aluminum Company of America    False      False       True
# 3    American -Austrian Magnesite Corporation     True      False      False
# 4                      American Bemberg Corp.    False       True       True
# ..                                        ...      ...        ...        ...
# 229                      Westhold Corporation     True      False      False
# 230             William R. Warner & Co., Inc.     True      False      False
# 231                       Witroth Corporation     True      False      False
# 232                   Wm. Wrigley Jr. Company    False      False       True
# 233      Worthington Pump and Machinery Corp.     True       True       True
#
# [234 rows x 4 columns]

# %%
tfr500_moodys32_moodys34.to_csv('output/tfr500_moodys32_moodys34.csv')

# %% [markdown]
# ### Tenenbaum

# %%
# Open the sheet
worksheet = client.open("Tenenbaum").worksheet("Sheet1 expanded")

# Get all records as list of dicts
records = worksheet.get_all_records()

# Convert to DataFrame
tenenbaum = pd.DataFrame(records)

bool_cols = ['mentions a subsidiary', 
             'mentions stock ownership',
             'subsidiary is AG',
             'subsidiary is GmbH',
             'mentions an affilated company',
             'mentions a plant/office/branch', 
             'is a subsidiary of a German firm',
             'other types of agreement']
tenenbaum[bool_cols] = tenenbaum[bool_cols].apply(lambda x: x == "TRUE")

# %%
tenenbaum_parent_list = tenenbaum.groupby("Master US firm name").agg(
    {
        "affiliated German firm name": list,
        "Master German firm name": list,
        **{col: "any" for col in bool_cols}
    }
).reset_index()

tenenbaum_parent_list = tenenbaum_parent_list[['Master US firm name']]

# %%
tfr500_moodys32_moodys34_tenenbaum = tfr500_moodys32_moodys34.merge(tenenbaum_parent_list, on='Master US firm name', how='outer', indicator=True)

tfr500_moodys32_moodys34_tenenbaum['TFR-500'] = tfr500_moodys32_moodys34_tenenbaum['TFR-500'].fillna(False)
tfr500_moodys32_moodys34_tenenbaum['Moodys 32'] = tfr500_moodys32_moodys34_tenenbaum['Moodys 32'].fillna(False)
tfr500_moodys32_moodys34_tenenbaum['Moodys 34'] = tfr500_moodys32_moodys34_tenenbaum['Moodys 34'].fillna(False)
tfr500_moodys32_moodys34_tenenbaum['Tenenbaum'] = tfr500_moodys32_moodys34_tenenbaum['_merge'].isin(['right_only', 'both'])

tfr500_moodys32_moodys34_tenenbaum = tfr500_moodys32_moodys34_tenenbaum.drop(columns='_merge')

first_cols = ['Master US firm name', 'TFR-500', 'Moodys 32', 'Moodys 34', 'Tenenbaum']
other_cols = [col for col in tfr500_moodys32_moodys34_tenenbaum.columns if col not in first_cols]

tfr500_moodys32_moodys34_tenenbaum = tfr500_moodys32_moodys34_tenenbaum[first_cols + other_cols]

tfr500_moodys32_moodys34_tenenbaum
# Out:
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_7381/348537660.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34_tenenbaum['TFR-500'] = tfr500_moodys32_moodys34_tenenbaum['TFR-500'].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_7381/348537660.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34_tenenbaum['Moodys 32'] = tfr500_moodys32_moodys34_tenenbaum['Moodys 32'].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_7381/348537660.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34_tenenbaum['Moodys 34'] = tfr500_moodys32_moodys34_tenenbaum['Moodys 34'].fillna(False)
#                           Master US firm name  TFR-500  Moodys 32  Moodys 34  \
# 0        Addressograph-Multigraph Corporation     True       True       True
# 1                       Alta United Mines Co.    False      False       True
# 2                 Aluminum Company of America    False      False       True
# 3                            Amber Mines Inc.    False      False      False
# 4    American -Austrian Magnesite Corporation     True      False      False
# ..                                        ...      ...        ...        ...
# 261             William R. Warner & Co., Inc.     True      False      False
# 262                      William Rhodes Davis    False      False      False
# 263                       Witroth Corporation     True      False      False
# 264                   Wm. Wrigley Jr. Company    False      False       True
# 265      Worthington Pump and Machinery Corp.     True       True       True
#
#      Tenenbaum
# 0         True
# 1        False
# 2        False
# 3         True
# 4        False
# ..         ...
# 261      False
# 262       True
# 263      False
# 264       True
# 265       True
#
# [266 rows x 5 columns]

# %% [markdown]
# ### HB 1932

# %%
# Open the sheet
worksheet = client.open("Handbuch 1932").worksheet("validated")

# Get all records as list of dicts
records = worksheet.get_all_records()

# Convert to DataFrame
hb1932 = pd.DataFrame(records)

# %%
hb1932_w_us_firm = hb1932[hb1932['US parent']!='']
hb1932_us_firm = hb1932_w_us_firm.groupby('Master US firm name')['corrected firm name'].agg(list).reset_index()

hb1932_us_firm = hb1932_us_firm[['Master US firm name']]

# %%
tfr500_moodys32_moodys34_tenenbaum_hb32 = tfr500_moodys32_moodys34_tenenbaum.merge(hb1932_us_firm.rename(columns={'corrected firm name': 'HB 1932 affiliated German firm name'}), 
                                                                                   on='Master US firm name', 
                                                                                   how='outer',
                                                                                   indicator=True)
tfr500_moodys32_moodys34_tenenbaum_hb32['TFR-500'] = tfr500_moodys32_moodys34_tenenbaum_hb32['TFR-500'].fillna(False)
tfr500_moodys32_moodys34_tenenbaum_hb32['Moodys 32'] = tfr500_moodys32_moodys34_tenenbaum_hb32['Moodys 32'].fillna(False)
tfr500_moodys32_moodys34_tenenbaum_hb32['Moodys 34'] = tfr500_moodys32_moodys34_tenenbaum_hb32['Moodys 34'].fillna(False)
tfr500_moodys32_moodys34_tenenbaum_hb32['Tenenbaum'] = tfr500_moodys32_moodys34_tenenbaum_hb32['Tenenbaum'].fillna(False)
tfr500_moodys32_moodys34_tenenbaum_hb32['HB 32'] = tfr500_moodys32_moodys34_tenenbaum_hb32['_merge'].isin(['right_only', 'both'])

tfr500_moodys32_moodys34_tenenbaum_hb32 = tfr500_moodys32_moodys34_tenenbaum_hb32.drop(columns='_merge')

first_cols = ['Master US firm name', 'TFR-500', 'Moodys 32', 'Moodys 34', 'Tenenbaum', 'HB 32']
other_cols = [col for col in tfr500_moodys32_moodys34_tenenbaum_hb32.columns if col not in first_cols]

tfr500_moodys32_moodys34_tenenbaum_hb32 = tfr500_moodys32_moodys34_tenenbaum_hb32[first_cols + other_cols]

tfr500_moodys32_moodys34_tenenbaum_hb32
# Out:
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_7381/1676133210.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34_tenenbaum_hb32['TFR-500'] = tfr500_moodys32_moodys34_tenenbaum_hb32['TFR-500'].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_7381/1676133210.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34_tenenbaum_hb32['Moodys 32'] = tfr500_moodys32_moodys34_tenenbaum_hb32['Moodys 32'].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_7381/1676133210.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34_tenenbaum_hb32['Moodys 34'] = tfr500_moodys32_moodys34_tenenbaum_hb32['Moodys 34'].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_7381/1676133210.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34_tenenbaum_hb32['Tenenbaum'] = tfr500_moodys32_moodys34_tenenbaum_hb32['Tenenbaum'].fillna(False)
#                           Master US firm name  TFR-500  Moodys 32  Moodys 34  \
# 0        Addressograph-Multigraph Corporation     True       True       True
# 1                       Alta United Mines Co.    False      False       True
# 2                 Aluminum Company of America    False      False       True
# 3                            Amber Mines Inc.    False      False      False
# 4    American -Austrian Magnesite Corporation     True      False      False
# ..                                        ...      ...        ...        ...
# 272             William R. Warner & Co., Inc.     True      False      False
# 273                      William Rhodes Davis    False      False      False
# 274                       Witroth Corporation     True      False      False
# 275                   Wm. Wrigley Jr. Company    False      False       True
# 276      Worthington Pump and Machinery Corp.     True       True       True
#
#      Tenenbaum  HB 32
# 0         True  False
# 1        False  False
# 2        False  False
# 3         True  False
# 4        False  False
# ..         ...    ...
# 272      False  False
# 273       True  False
# 274      False  False
# 275       True   True
# 276       True  False
#
# [277 rows x 6 columns]

# %% [markdown]
# ### HB 1934

# %%
# Open the sheet
worksheet = client.open("Handbuch 1934").worksheet("validated")

# Get all records as list of dicts
records = worksheet.get_all_records()

# Convert to DataFrame
hb1934 = pd.DataFrame(records)

# %%
hb1934_w_us_firm = hb1934[hb1934['US parent']!='']
hb1934_us_firm = hb1934_w_us_firm.groupby('Master US firm name')['corrected firm name'].agg(list).reset_index()

hb1934_us_firm = hb1934_us_firm[['Master US firm name']]

# %%
tfr500_moodys32_moodys34_tenenbaum_hb32_hb34 = tfr500_moodys32_moodys34_tenenbaum_hb32.merge(hb1934_us_firm.rename(columns={'corrected firm name': 'HB 1934 affiliated German firm name'}), 
                                                                                   on='Master US firm name', 
                                                                                   how='outer',
                                                                                   indicator=True)
tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['TFR-500'] = tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['TFR-500'].fillna(False)
tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['Moodys 32'] = tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['Moodys 32'].fillna(False)
tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['Moodys 34'] = tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['Moodys 34'].fillna(False)
tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['Tenenbaum'] = tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['Tenenbaum'].fillna(False)
tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['HB 32'] = tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['HB 32'].fillna(False)
tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['HB 34'] = tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['_merge'].isin(['right_only', 'both'])


tfr500_moodys32_moodys34_tenenbaum_hb32_hb34 = tfr500_moodys32_moodys34_tenenbaum_hb32_hb34.drop(columns='_merge')

first_cols = ['Master US firm name', 'TFR-500', 'Moodys 32', 'Moodys 34', 'Tenenbaum', 'HB 32', 'HB 34']
other_cols = [col for col in tfr500_moodys32_moodys34_tenenbaum_hb32_hb34.columns if col not in first_cols]

tfr500_moodys32_moodys34_tenenbaum_hb32_hb34 = tfr500_moodys32_moodys34_tenenbaum_hb32_hb34[first_cols + other_cols]

tfr500_moodys32_moodys34_tenenbaum_hb32_hb34
# Out:
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_7381/3888167258.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['TFR-500'] = tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['TFR-500'].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_7381/3888167258.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['Moodys 32'] = tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['Moodys 32'].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_7381/3888167258.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['Moodys 34'] = tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['Moodys 34'].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_7381/3888167258.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['Tenenbaum'] = tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['Tenenbaum'].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_7381/3888167258.py:9: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['HB 32'] = tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['HB 32'].fillna(False)
#                           Master US firm name  TFR-500  Moodys 32  Moodys 34  \
# 0        Addressograph-Multigraph Corporation     True       True       True
# 1                       Alta United Mines Co.    False      False       True
# 2                 Aluminum Company of America    False      False       True
# 3                            Amber Mines Inc.    False      False      False
# 4    American -Austrian Magnesite Corporation     True      False      False
# ..                                        ...      ...        ...        ...
# 274             William R. Warner & Co., Inc.     True      False      False
# 275                      William Rhodes Davis    False      False      False
# 276                       Witroth Corporation     True      False      False
# 277                   Wm. Wrigley Jr. Company    False      False       True
# 278      Worthington Pump and Machinery Corp.     True       True       True
#
#      Tenenbaum  HB 32  HB 34
# 0         True  False  False
# 1        False  False  False
# 2        False  False  False
# 3         True  False  False
# 4        False  False  False
# ..         ...    ...    ...
# 274      False  False  False
# 275       True  False  False
# 276      False  False  False
# 277       True   True   True
# 278       True  False  False
#
# [279 rows x 7 columns]

# %% [markdown]
# ### HB GmbH 32

# %%
hb_gmbh = pd.read_excel('../../Moodys_name_to_handbuch/output/manual/gmbh_validated.xlsx', sheet_name='validated')
hb_gmbh = hb_gmbh[hb_gmbh['validated'].isin(['USC', 'USO', 'USOP'])]

hb_gmbh["is_duplicate"] = hb_gmbh.duplicated(subset=['Master German firm name', 'Master US firm name'])
# dropping duplicates
hb_gmbh = hb_gmbh[hb_gmbh["is_duplicate"] == False]

hb_gmbh = hb_gmbh[['german_name', 'Master German firm name', 'US_name', 'Master US firm name', 'validated']]
hb_gmbh
# Out:
#                           german_name  \
# 1               American News Company
# 2                       Columbia Film
# 3                             O-Cedar
# 4                           Fairbanks
# 5           Gillette Safety Razor Co.
# 6                       Addressograph
# 7                     Aeolian Company
# 8                American Oil Company
# 9                            Bakelite
# 10          Bausch & Lomb Optical Co.
# 11                          Blaw-Knox
# 12            Boston Blacking Company
# 13                    Butler Brothers
# 14  Chesebrough Manufacturing Company
# 15                          Coca-Cola
# 17                  Corn Products Co.
# 18          Deutsche Celotex Vertrieb
# 19   Deutsche Underwood Elliot Fisher
# 20                      Durant Motors
# 21      Eagle Oil Company of New York
# 22                         Elektrolux
# 23                     General Motors
# 24                   Hobart Maschinen
# 25                     Ingersoll-Rand
# 26    International Harvester Company
# 27               Kraft Cheese Company
# 28                         Parker Pen
# 29    Philip Morris & Company Limited
# 30                Quaker Oats Company
# 31                Reece Machinery Co.
# 32               S. Oppenheimer & Co.
# 33    German American Tobacco Company
# 34             Holophane-Gesellschaft
# 35                        Hupp Motors
# 36                W. T. Grant Company
#
#                        Master German firm name  \
# 1                        American News Company
# 2                                Columbia Film
# 3                                      O-Cedar
# 4               The Fairbanks G.m.b.H. Company
# 5                    Gillette Safety Razor Co.
# 6            Addressograph-Multigraph G.m.b.H.
# 7                              Aeolian Company
# 8                         American Oil Company
# 9                        Bakelite Gesellschaft
# 10                   Bausch & Lomb Optical Co.
# 11                                   Blaw-Knox
# 12            Boston Blacking Company G.m.b.H.
# 13                   Butler Brothers, G.m.b.H.
# 14      Chesebrough Manufacturing Co. G.m.b.H.
# 15                          Coca-Cola G.m.b.H.
# 17                           Corn Products Co.
# 18                   Deutsche Celotex Vertrieb
# 19  Deutsche Underwood Elliott Fisher G.m.b.H.
# 20                               Durant Motors
# 21               Eagle Oil Company of New York
# 22                                  Elektrolux
# 23                     General Motors G.m.b.H.
# 24       Hobart Gesellschaft, Hamburg, Germany
# 25                              Ingersoll-Rand
# 26     International Harvester Company, m.b.H.
# 27                  Kraft Kaese Werke G.m.b.H.
# 28   Parker Pen Co., G.m.b.H., Berlin, Germany
# 29        Philip Morris & Co. Limited G.m.b.H.
# 30                    Quaker Oats Co. G.m.b.H.
# 31                     Reece Machinery Company
# 32                        S. Oppenheimer & Co.
# 33                 German-American Tobacco Co.
# 34                      Holophane-Gesellschaft
# 35                                 Hupp Motors
# 36                         W. T. Grant Company
#
#                                   US_name  \
# 1             American News Company, Inc.
# 2           Columbia Pictures Corporation
# 3                     O-Cedar Corporation
# 4                       Fairbanks Company
# 5               Gillette Safety Razor Co.
# 6                   Addressograph Company
# 7                         Aeolian Company
# 8                    American Oil Company
# 9                    Bakelite Corporation
# 10          Bausch & Lomb Optical Company
# 11                      Blaw-Knox Company
# 12                Boston Blacking Company
# 13                        Butler Brothers
# 14  Chesebrough Manufacturing Co. (Cons.)
# 15    Coca-Cola International Corporation
# 17         Corn Products Refining Company
# 18                        Celotex Company
# 19       Underwood Elliott Fisher Company
# 20                    Durant Motors, Inc.
# 21                      Eagle Oil Company
# 22          Electrolux Servel Corporation
# 23             General Motors Corporation
# 24           Hobart Manufacturing Company
# 25                 Ingersoll-Rand Company
# 26        International Harvester Company
# 27        Kraft-Phenix Cheese Corporation
# 28                     Parker Pen Company
# 29        Philip Morris & Co., Ltd., Ind.
# 30                    Quaker Oats Company
# 31          Reece Folding Machine Company
# 32             Oppenheimer (S.) & Company
# 33            German-American Tobacco Co.
# 34                Holophane Company, Inc.
# 35             Hupp Motor Car Corporation
# 36                 Grant, (W. T.) Company
#
#                                   Master US firm name validated
# 1                         American News Company, Inc.       USC
# 2                             Columbia Pictures Corp.       USC
# 3                                 O-Cedar Corporation       USC
# 4                               The Fairbanks Company       USO
# 5                       Gillette Safety Rasor Company       USO
# 6                Addressograph-Multigraph Corporation       USO
# 7                                     Aeolian Company       USO
# 8                                American Oil Company       USO
# 9                                      Bakelite Corp.       USO
# 10                          Bausch & Lomb Optical Co.       USO
# 11                                      Blaw-Knox Co.       USO
# 12                  United Shoe Machinery Corporation       USO
# 13                                    Butler Brothers       USO
# 14         Chesebrough Manufacturing Co. Consolidated       USO
# 15  The Coca-Cola Company (101 W. 10th Street Wilm...       USO
# 17                     Corn Products Refining Company       USO
# 18                                        Celotex Co.       USO
# 19                   Underwood Elliott Fisher Company       USO
# 20                                Durant Motors, Inc.       USO
# 21                                  Eagle Oil Company       USO
# 22                                       Servel, Inc.       USO
# 23   General Motors Corporation (Overseas Operations)       USO
# 24                   The Hobart Manufacturing Company       USO
# 25                             Ingersoll-Rand Company       USO
# 26                    International Harvester Company       USO
# 27                               Kraft Cheese Company       USO
# 28                                     Parker Pen Co.       USO
# 29                     Philip Morris & Co. Ltd., Inc.       USO
# 30                                    Quaker Oats Co.       USO
# 31  The International Button Hole Sewing Machine C...       USO
# 32                         Oppenheimer (S.) & Company       USO
# 33                        German-American Tobacco Co.       USO
# 34                            Holophane Company, Inc.      USOP
# 35                         Hupp Motor Car Corporation      USOP
# 36                             Grant, (W. T.) Company      USOP

# %%
hb_gmbh_parent = hb_gmbh.groupby('Master US firm name')['Master German firm name'].agg(list).reset_index()
hb_gmbh_parent = hb_gmbh_parent[['Master US firm name']]

# %%
parent_large_table = tfr500_moodys32_moodys34_tenenbaum_hb32_hb34.merge(hb_gmbh_parent,
                                                                         on='Master US firm name', 
                                                                         how='outer',
                                                                         indicator=True)
parent_large_table['TFR-500'] = parent_large_table['TFR-500'].fillna(False)
parent_large_table['Moodys 32'] = parent_large_table['Moodys 32'].fillna(False)
parent_large_table['Moodys 34'] = parent_large_table['Moodys 34'].fillna(False)
parent_large_table['Tenenbaum'] = parent_large_table['Tenenbaum'].fillna(False)
parent_large_table['HB 32'] = parent_large_table['HB 32'].fillna(False)
parent_large_table['HB 34'] = parent_large_table['HB 34'].fillna(False)
parent_large_table['HB GmbH'] = parent_large_table['_merge'].isin(['right_only', 'both'])


parent_large_table = parent_large_table.drop(columns='_merge')

first_cols = ['Master US firm name', 'TFR-500', 'Moodys 32', 'Moodys 34', 'Tenenbaum', 'HB 32', 'HB 34', 'HB GmbH']
other_cols = [col for col in parent_large_table.columns if col not in first_cols]

parent_large_table = parent_large_table[first_cols + other_cols]

parent_large_table
# Out:
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_7381/1982997914.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   parent_large_table['TFR-500'] = parent_large_table['TFR-500'].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_7381/1982997914.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   parent_large_table['Moodys 32'] = parent_large_table['Moodys 32'].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_7381/1982997914.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   parent_large_table['Moodys 34'] = parent_large_table['Moodys 34'].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_7381/1982997914.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   parent_large_table['Tenenbaum'] = parent_large_table['Tenenbaum'].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_7381/1982997914.py:9: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   parent_large_table['HB 32'] = parent_large_table['HB 32'].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_7381/1982997914.py:10: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   parent_large_table['HB 34'] = parent_large_table['HB 34'].fillna(False)
#                       Master US firm name  TFR-500  Moodys 32  Moodys 34  \
# 0    Addressograph-Multigraph Corporation     True       True       True
# 1                         Aeolian Company    False      False      False
# 2                   Alta United Mines Co.    False      False       True
# 3             Aluminum Company of America    False      False       True
# 4                        Amber Mines Inc.    False      False      False
# ..                                    ...      ...        ...        ...
# 286         William R. Warner & Co., Inc.     True      False      False
# 287                  William Rhodes Davis    False      False      False
# 288                   Witroth Corporation     True      False      False
# 289               Wm. Wrigley Jr. Company    False      False       True
# 290  Worthington Pump and Machinery Corp.     True       True       True
#
#      Tenenbaum  HB 32  HB 34  HB GmbH
# 0         True  False  False     True
# 1        False  False  False     True
# 2        False  False  False    False
# 3        False  False  False    False
# 4         True  False  False    False
# ..         ...    ...    ...      ...
# 286      False  False  False    False
# 287       True  False  False    False
# 288      False  False  False    False
# 289       True   True   True    False
# 290       True  False  False    False
#
# [291 rows x 8 columns]

# %%
parent_large_table_to_csv = parent_large_table[['Master US firm name', 'TFR-500', 'Tenenbaum', 'Moodys 32', 'Moodys 34', 'HB 32', 'HB 34', 'HB GmbH']]
parent_large_table_to_csv = parent_large_table_to_csv.rename(columns={'Master US firm name': 'US Company'})
parent_large_table_to_csv.to_csv('output/parent_union.csv', index=False)

# %% [markdown]
# ## Analysis

# %%
kw = ''
tfr500_moodys32_moodys34_tenenbaum_hb32_hb34[tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['Master US firm name'].str.contains(kw, case=False)]
# Out:
#                           Master US firm name  in TFR-500  in Moodys 32  \
# 0        Addressograph-Multigraph Corporation        True          True
# 1                       Alta United Mines Co.       False         False
# 2                 Aluminum Company of America       False         False
# 3                            Amber Mines Inc.       False         False
# 4    American -Austrian Magnesite Corporation        True         False
# ..                                        ...         ...           ...
# 274             William R. Warner & Co., Inc.        True         False
# 275                      William Rhodes Davis       False         False
# 276                       Witroth Corporation        True         False
# 277                   Wm. Wrigley Jr. Company       False         False
# 278      Worthington Pump and Machinery Corp.        True          True
#
#      in Moodys 34  in Tenenbaum  in HB 32  in HB 34  \
# 0            True          True     False     False
# 1            True         False     False     False
# 2            True         False     False     False
# 3           False          True     False     False
# 4           False         False     False     False
# ..            ...           ...       ...       ...
# 274         False         False     False     False
# 275         False          True     False     False
# 276         False         False     False     False
# 277          True          True      True      True
# 278          True          True     False     False
#
#                                affiliated German firms type_Partnership  \
# 0                  [Addressograph-Multigraph G.m.b.H.]            False
# 1                                                  NaN              NaN
# 2                                                  NaN              NaN
# 3                                                  NaN              NaN
# 4    [Deutsche Heraklith A.G., Deutsche Heraklith A...            False
# ..                                                 ...              ...
# 274  [Godecke & Co. Chemische Fabrik A.G., Godecke ...            False
# 275                                                NaN              NaN
# 276    [Oppelener Lagerhaus Gesellschaft, Ostrhederei]            False
# 277                                                NaN              NaN
# 278         [Deutsche Worthington Gesellschaft m.b.H.]            False
#
#     type_branch  ... mentions a subsidiary mentions stock ownership  \
# 0         False  ...                  True                    False
# 1           NaN  ...                   NaN                      NaN
# 2           NaN  ...                   NaN                      NaN
# 3           NaN  ...                 False                    False
# 4         False  ...                   NaN                      NaN
# ..          ...  ...                   ...                      ...
# 274       False  ...                   NaN                      NaN
# 275         NaN  ...                  True                    False
# 276       False  ...                   NaN                      NaN
# 277         NaN  ...                 False                    False
# 278       False  ...                  True                    False
#
#     subsidiary is AG subsidiary is GmbH mentions an affilated company  \
# 0              False               True                         False
# 1                NaN                NaN                           NaN
# 2                NaN                NaN                           NaN
# 3              False              False                         False
# 4                NaN                NaN                           NaN
# ..               ...                ...                           ...
# 274              NaN                NaN                           NaN
# 275             True              False                         False
# 276              NaN                NaN                           NaN
# 277             True              False                         False
# 278            False               True                         False
#
#     mentions a plant/office/branch is a subsidiary of a German firm  \
# 0                            False                            False
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                            False                             True
# 4                              NaN                              NaN
# ..                             ...                              ...
# 274                            NaN                              NaN
# 275                          False                            False
# 276                            NaN                              NaN
# 277                          False                            False
# 278                          False                            False
#
#     other types of agreement HB 1932 affiliated German firm name  \
# 0                      False                                 NaN
# 1                        NaN                                 NaN
# 2                        NaN                                 NaN
# 3                      False                                 NaN
# 4                        NaN                                 NaN
# ..                       ...                                 ...
# 274                      NaN                                 NaN
# 275                    False                                 NaN
# 276                      NaN                                 NaN
# 277                    False        [Wrigley Aktiengesellschaft]
# 278                    False                                 NaN
#
#     HB 1934 affiliated German firm name
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 274                                 NaN
# 275                                 NaN
# 276                                 NaN
# 277       [Wrigley Aktiengesellschaft.]
# 278                                 NaN
#
# [279 rows x 44 columns]

# %%
tfr500_moodys32_moodys34_tenenbaum_hb32_hb34[(tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['in Moodys 32']) |
                                        (tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['in Moodys 34']) | 
                                        (tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['in HB 32']) |
                                        (tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['in HB 34'])]
# Out:
#                        Master US firm name  in TFR-500  in Moodys 32  \
# 0     Addressograph-Multigraph Corporation        True          True
# 1                    Alta United Mines Co.       False         False
# 2              Aluminum Company of America       False         False
# 6                   American Bemberg Corp.       False          True
# 7                     American Can Company       False          True
# ..                                     ...         ...           ...
# 264                      Valvoline Oil Co.       False         False
# 265  W. A. Harriman & Co., Inc., New York.       False         False
# 268                            Warner Bros       False         False
# 277                Wm. Wrigley Jr. Company       False         False
# 278   Worthington Pump and Machinery Corp.        True          True
#
#      in Moodys 34  in Tenenbaum  in HB 32  in HB 34  \
# 0            True          True     False     False
# 1            True         False     False     False
# 2            True         False     False     False
# 6            True         False     False     False
# 7            True         False     False     False
# ..            ...           ...       ...       ...
# 264          True         False     False     False
# 265         False         False      True      True
# 268         False         False      True     False
# 277          True          True      True      True
# 278          True          True     False     False
#
#                         affiliated German firms type_Partnership type_branch  \
# 0           [Addressograph-Multigraph G.m.b.H.]            False       False
# 1                                           NaN              NaN         NaN
# 2                                           NaN              NaN         NaN
# 6                                           NaN              NaN         NaN
# 7                                           NaN              NaN         NaN
# ..                                          ...              ...         ...
# 264                                         NaN              NaN         NaN
# 265                                         NaN              NaN         NaN
# 268                                         NaN              NaN         NaN
# 277                                         NaN              NaN         NaN
# 278  [Deutsche Worthington Gesellschaft m.b.H.]            False       False
#
#      ... mentions a subsidiary mentions stock ownership subsidiary is AG  \
# 0    ...                  True                    False            False
# 1    ...                   NaN                      NaN              NaN
# 2    ...                   NaN                      NaN              NaN
# 6    ...                   NaN                      NaN              NaN
# 7    ...                   NaN                      NaN              NaN
# ..   ...                   ...                      ...              ...
# 264  ...                   NaN                      NaN              NaN
# 265  ...                   NaN                      NaN              NaN
# 268  ...                   NaN                      NaN              NaN
# 277  ...                 False                    False             True
# 278  ...                  True                    False            False
#
#     subsidiary is GmbH mentions an affilated company  \
# 0                 True                         False
# 1                  NaN                           NaN
# 2                  NaN                           NaN
# 6                  NaN                           NaN
# 7                  NaN                           NaN
# ..                 ...                           ...
# 264                NaN                           NaN
# 265                NaN                           NaN
# 268                NaN                           NaN
# 277              False                         False
# 278               True                         False
#
#     mentions a plant/office/branch is a subsidiary of a German firm  \
# 0                            False                            False
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 6                              NaN                              NaN
# 7                              NaN                              NaN
# ..                             ...                              ...
# 264                            NaN                              NaN
# 265                            NaN                              NaN
# 268                            NaN                              NaN
# 277                          False                            False
# 278                          False                            False
#
#     other types of agreement            HB 1932 affiliated German firm name  \
# 0                      False                                            NaN
# 1                        NaN                                            NaN
# 2                        NaN                                            NaN
# 6                        NaN                                            NaN
# 7                        NaN                                            NaN
# ..                       ...                                            ...
# 264                      NaN                                            NaN
# 265                      NaN  [Deutsch-Atlantische Telegraphengesellschaft]
# 268                      NaN    [Tobis Tonbild-Syndikat Aktiengesellschaft]
# 277                    False                   [Wrigley Aktiengesellschaft]
# 278                    False                                            NaN
#
#                    HB 1934 affiliated German firm name
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# ..                                                 ...
# 264                                                NaN
# 265  [Vereinigte Königs- und Laurahütte, Actien-Ges...
# 268                                                NaN
# 277                      [Wrigley Aktiengesellschaft.]
# 278                                                NaN
#
# [136 rows x 44 columns]

# %%
tfr500_moodys32_moodys34_tenenbaum_hb32_hb34[((tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['in Moodys 32']) |
                                        (tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['in Moodys 34']) | 
                                        (tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['in HB 32']) |
                                        (tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['in HB 34'])) & 
                                        (tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['in TFR-500'])]
# Out:
#                                    Master US firm name  in TFR-500  \
# 0                 Addressograph-Multigraph Corporation        True
# 14   American Radiator & Standard Sanitary Corporation        True
# 25                    Bavarian oil and Gas Corporation        True
# 31                    Burroughs Adding Machine Company        True
# 41                          Chicago Pneumatic Tool Co.        True
# 42                          Colgate-Palmolive-Peet Co.        True
# 44                     Combustion Engineering Co. Inc.        True
# 50                      Corn Products Refining company        True
# 60                 E.I. du Pont de Nemours and Company        True
# 61                               Eastman Kodak Company        True
# 64                           Eitingon Schild Co., Inc.        True
# 71                                 F. W. Woolworth Co.        True
# 74                                  Ford Motor Company        True
# 80               General Motors Acceptance Corporation        True
# 81    General Motors Corporation (Overseas Operations)        True
# 86                                Gulf Oil Corporation        True
# 93                            Hugo Stinnes Corporation        True
# 94                       Hugo Stinnes Industries, Inc.        True
# 95                      I. B. Kleinert Rubbert Company        True
# 98                International Business Machine Corp.        True
# 100        International General Electric Company Inc.        True
# 101                    International Harvester Company        True
# 108        International Telephone and Telegraph Corp.        True
# 109                              Intertype Corporation        True
# 118              L. C. Smith & Corona Typewriters Inc.        True
# 119                   Lehn & Pink Products Corporation        True
# 125                                Loew's Incorporated        True
# 128                                Magdalena Syndicate        True
# 130                              Markt & Hammacher Co.        True
# 132                      Mergenthaler Linotype Company        True
# 138                              National Lead Company        True
# 143                           North European Oil Corp.        True
# 145                                     Norton Company        True
# 149                              Otis Elevator Company        True
# 152                           Paramount Pictures, Inc.        True
# 164                                    Quaker Oats Co.        True
# 168                                Remington Rand Inc.        True
# 172  Ritter Company, Inc. (Formerly Ritter Dental M...        True
# 177                     Royal Typewriter Company, Inc.        True
# 186                        Signode Steel Strapping Co.        True
# 189                    Socony-Vacuum Oil Company, Inc.        True
# 194              Standard Commercial Tobacco Co., Inc.        True
# 197                  Standard Oil Company (New Jersey)        True
# 208                      The Atlantic Refining Company        True
# 209                       The Babcock & Wilcox Company        True
# 221                   The Hobart Manufacturing Company        True
# 224  The International Button Hole Sewing Machine C...        True
# 230                 The National Cash Register Company        True
# 233                                   The Pfaudler Co.        True
# 237                                  The Stanley Works        True
# 239                             The Torrington Company        True
# 242             The Yale & Towne Manufacturing Company        True
# 243                      Tide Water Associated Oil Co.        True
# 245                            Titeflex Metal Hose Co.        True
# 249                   Twentieth Century-Fox Film Corp.        True
# 251                   Underwood Elliott Fisher Company        True
# 259        United States Hoffman Machinery Corporation        True
# 262                          United Statess Lines, Co.        True
# 263                        Universal Picture Co., Inc.        True
# 278               Worthington Pump and Machinery Corp.        True
#
#      in Moodys 32  in Moodys 34  in Tenenbaum  in HB 32  in HB 34  \
# 0            True          True          True     False     False
# 14           True          True          True     False     False
# 25          False         False         False      True      True
# 31           True          True          True     False     False
# 41           True          True          True     False     False
# 42           True          True          True     False     False
# 44           True         False         False     False     False
# 50          False         False          True     False      True
# 60           True          True          True      True      True
# 61           True          True          True      True     False
# 64           True          True         False      True      True
# 71           True          True          True     False     False
# 74           True          True          True      True      True
# 80           True          True         False     False     False
# 81           True          True          True      True      True
# 86           True          True         False     False     False
# 93           True          True          True     False     False
# 94           True          True          True     False     False
# 95           True          True         False     False     False
# 98           True         False          True     False     False
# 100          True          True          True      True      True
# 101          True          True          True     False     False
# 108         False         False          True      True      True
# 109          True          True         False     False     False
# 118          True          True         False     False     False
# 119         False          True         False     False     False
# 125         False         False         False      True     False
# 128          True         False         False      True     False
# 130         False          True         False     False     False
# 132          True          True          True     False     False
# 138          True          True          True     False     False
# 143          True          True         False     False     False
# 145          True          True          True     False     False
# 149         False          True          True     False     False
# 152          True          True         False      True      True
# 164          True          True         False     False     False
# 168          True          True          True      True     False
# 172          True          True          True      True      True
# 177          True          True          True     False     False
# 186          True          True         False     False     False
# 189         False         False          True      True     False
# 194          True         False         False     False     False
# 197          True          True          True      True      True
# 208         False          True          True     False     False
# 209         False         False         False     False      True
# 221          True          True         False     False     False
# 224          True          True         False     False     False
# 230         False          True          True     False     False
# 233          True          True         False      True     False
# 237          True         False         False     False     False
# 239          True          True          True     False     False
# 242          True          True          True      True     False
# 243         False          True          True     False     False
# 245         False         False         False      True      True
# 249          True          True          True      True     False
# 251          True          True          True      True      True
# 259         False          True          True     False     False
# 262         False          True         False     False     False
# 263         False          True          True     False     False
# 278          True          True          True     False     False
#
#                                affiliated German firms type_Partnership  \
# 0                  [Addressograph-Multigraph G.m.b.H.]            False
# 14            [Nationale Radiator Gesellschaft m.b.H.]            False
# 25                 [Bayerische Mineral-Industrie A.G.]            False
# 31           [Deutsche Burroughs Rechenmaschinen A.G.]            False
# 41   [Internationale Pressluft und Elektricitats Ge...            False
# 42                [Palmolive-Binder & Ketals G.m.b.H.]            False
# 44             [Kohlenscheidungs-Gesellschaft, m.b.H.]            False
# 50   [Aktien-Malsfabrik Landsburg, A. G., Convertga...            False
# 60                           [Duco Aktiengesellschaft]            False
# 61                          [Kodak Aktiengesellschaft]            False
# 64            [Ch. Eitingon, A.G., Kurt Wachtel, A.G.]            False
# 71          [F. W. Woolworth Co., F. W. Woolworth Co.]            False
# 74                  [Ford Werke A.G., Ford Werke A.G.]            False
# 80      [Allgemeine Finanzierungs Gesellschaft m.b.H.]            False
# 81   [Adam Opel Aktiengsellschaft, Frigidaire G.m.b...            False
# 86           [Maschinenoel Import Gesellschaft m.b.H.]            False
# 93   [Eisenlager G.m.b.H., Freidreichstrasse, 12, G...            False
# 94   [Anker Kohlen & Brikettwerke G.m.b.H., Artus H...            False
# 95   [Kleinerts Hanseatische, Gummiwerke Gesellscha...            False
# 98   [Deutsche Hollerith Maschinen Gesellschaft, m....            False
# 100             [Osram G.m.b.H. Kommanditgesellschaft]             True
# 101          [International Harvester Company, m.b.H.]            False
# 108  [Baruta Import and Export, GmbH, Baruta Import...            False
# 109  [Intertype Fabrik G.m.b.H., Intertype Setzmasc...            False
# 118   [L. C. Smith & Corona Schreihmaschinen G.m.b.H.]            False
# 119                                 [A. S. Hinds A.G.]            False
# 125                    [Metro-Goldwyn Mayer Film A.G.]            False
# 128  [Edoel-Bergbau Aktiengesellschaft Celle Nordde...            False
# 130                                      [Markt & Co.]            False
# 132  [Linotype, G.m.b.H., Mergenthaler Setzmaschine...            False
# 138                  [Zinnwerke Wilheimsburg G.m.b.H.]            False
# 143                            [Nord-Europaeische Oel]            False
# 145             [Deutsche Norton-Gesellschaft, m.b.H.]            False
# 149                       [Otis Aufzugswerke G.m.b.H.]            False
# 152                [Paramount Film Aktiengesellschaft]            False
# 164  [Quaker Nahrmittel, G.m.b.H., Quaker Oats Co. ...            False
# 168  [Jahresuhren Fabrik G.m.b.H., Kardex A.G., Kar...            False
# 172                                     [Ritter, A.G.]            False
# 177  [Orga Akt. Ges., Royal Schreihmaschinen, G.m.b...            False
# 186                          [Signode System G.m.b.H.]            False
# 189  [Deutsche Vacuum Oel A.G., Erdolbergbau A.G., ...            False
# 194                                 [Werkhof G.m.b.H.]            False
# 197  [Allgemeine Oel-Handels-Gesellschaft mit besch...            False
# 208  [Allgemeine Oel-Handels, GmbH. (Oelhag), The A...            False
# 209                       [Deustche Babcock & Wilcock]            False
# 221            [Hobart Maschinen Gesellschaft, m.b.H.]            False
# 224                          [Reece Machinery Company]            False
# 230        [National-Krupp Registrier-Kassen G.m.b.H.]            False
# 233                             [Pfaudler Werke, A.G.]            False
# 237                       [The Stanley Works G.m.b.H.]            False
# 239                           [Metallkentor, G.m.b.H.]            False
# 242  [Brankaer Eisenwerke, Damm & Ladwig Kommandit ...            False
# 243         [Hamburg-Amerikanische Mineralol-G.m.b.H.]            False
# 245              [Europaische Titeflex Metallschlaush]            False
# 249  [Deutsche-Fox Film A.G., Fox Tonende Wochenschau]            False
# 251  [Adrema Maschinenebau G.m.b.H., Deutsche Under...            False
# 259       [Hoffman Bugelmaschinen Gesellschaft m.b.H.]            False
# 262                                [Rosskai, G.m.b.H.]            False
# 263                    [Deutsche Universal Film, A.G.]            False
# 278         [Deutsche Worthington Gesellschaft m.b.H.]            False
#
#     type_branch  ... mentions a subsidiary mentions stock ownership  \
# 0         False  ...                  True                    False
# 14        False  ...                  True                    False
# 25        False  ...                   NaN                      NaN
# 31        False  ...                  True                    False
# 41        False  ...                  True                    False
# 42        False  ...                  True                    False
# 44        False  ...                   NaN                      NaN
# 50        False  ...                  True                    False
# 60        False  ...                  True                     True
# 61        False  ...                  True                    False
# 64        False  ...                   NaN                      NaN
# 71         True  ...                  True                    False
# 74        False  ...                  True                    False
# 80        False  ...                   NaN                      NaN
# 81        False  ...                  True                     True
# 86        False  ...                   NaN                      NaN
# 93        False  ...                 False                    False
# 94         True  ...                  True                     True
# 95        False  ...                   NaN                      NaN
# 98        False  ...                 False                    False
# 100       False  ...                  True                     True
# 101       False  ...                  True                    False
# 108       False  ...                  True                     True
# 109       False  ...                   NaN                      NaN
# 118       False  ...                   NaN                      NaN
# 119       False  ...                   NaN                      NaN
# 125       False  ...                   NaN                      NaN
# 128       False  ...                   NaN                      NaN
# 130       False  ...                   NaN                      NaN
# 132       False  ...                  True                    False
# 138       False  ...                  True                    False
# 143       False  ...                   NaN                      NaN
# 145       False  ...                  True                    False
# 149       False  ...                  True                    False
# 152       False  ...                   NaN                      NaN
# 164       False  ...                   NaN                      NaN
# 168       False  ...                  True                    False
# 172       False  ...                  True                    False
# 177       False  ...                  True                    False
# 186       False  ...                   NaN                      NaN
# 189       False  ...                  True                    False
# 194       False  ...                   NaN                      NaN
# 197       False  ...                  True                    False
# 208       False  ...                  True                    False
# 209       False  ...                   NaN                      NaN
# 221       False  ...                   NaN                      NaN
# 224       False  ...                   NaN                      NaN
# 230       False  ...                  True                    False
# 233       False  ...                   NaN                      NaN
# 237       False  ...                   NaN                      NaN
# 239       False  ...                  True                    False
# 242       False  ...                  True                    False
# 243       False  ...                  True                    False
# 245       False  ...                   NaN                      NaN
# 249       False  ...                  True                    False
# 251       False  ...                  True                     True
# 259       False  ...                  True                    False
# 262       False  ...                   NaN                      NaN
# 263       False  ...                  True                    False
# 278       False  ...                  True                    False
#
#     subsidiary is AG subsidiary is GmbH mentions an affilated company  \
# 0              False               True                         False
# 14             False               True                         False
# 25               NaN                NaN                           NaN
# 31              True              False                         False
# 41              True               True                         False
# 42             False               True                         False
# 44               NaN                NaN                           NaN
# 50              True               True                         False
# 60              True              False                         False
# 61              True              False                         False
# 64               NaN                NaN                           NaN
# 71             False               True                         False
# 74              True              False                         False
# 80               NaN                NaN                           NaN
# 81              True               True                         False
# 86               NaN                NaN                           NaN
# 93             False              False                         False
# 94              True               True                         False
# 95               NaN                NaN                           NaN
# 98             False              False                         False
# 100             True              False                         False
# 101            False               True                         False
# 108             True               True                         False
# 109              NaN                NaN                           NaN
# 118              NaN                NaN                           NaN
# 119              NaN                NaN                           NaN
# 125              NaN                NaN                           NaN
# 128              NaN                NaN                           NaN
# 130              NaN                NaN                           NaN
# 132            False               True                         False
# 138            False               True                         False
# 143              NaN                NaN                           NaN
# 145            False               True                         False
# 149            False               True                         False
# 152              NaN                NaN                           NaN
# 164              NaN                NaN                           NaN
# 168            False               True                         False
# 172             True              False                         False
# 177            False               True                         False
# 186              NaN                NaN                           NaN
# 189             True              False                         False
# 194              NaN                NaN                           NaN
# 197             True              False                         False
# 208            False               True                         False
# 209              NaN                NaN                           NaN
# 221              NaN                NaN                           NaN
# 224              NaN                NaN                           NaN
# 230            False               True                         False
# 233              NaN                NaN                           NaN
# 237              NaN                NaN                           NaN
# 239            False               True                         False
# 242            False              False                         False
# 243            False               True                         False
# 245              NaN                NaN                           NaN
# 249             True              False                         False
# 251             True              False                         False
# 259            False               True                         False
# 262              NaN                NaN                           NaN
# 263             True              False                         False
# 278            False               True                         False
#
#     mentions a plant/office/branch is a subsidiary of a German firm  \
# 0                            False                            False
# 14                           False                            False
# 25                             NaN                              NaN
# 31                           False                            False
# 41                           False                            False
# 42                           False                            False
# 44                             NaN                              NaN
# 50                           False                            False
# 60                           False                            False
# 61                           False                            False
# 64                             NaN                              NaN
# 71                           False                            False
# 74                            True                            False
# 80                             NaN                              NaN
# 81                           False                            False
# 86                             NaN                              NaN
# 93                           False                            False
# 94                           False                            False
# 95                             NaN                              NaN
# 98                            True                            False
# 100                          False                            False
# 101                           True                            False
# 108                          False                            False
# 109                            NaN                              NaN
# 118                            NaN                              NaN
# 119                            NaN                              NaN
# 125                            NaN                              NaN
# 128                            NaN                              NaN
# 130                            NaN                              NaN
# 132                          False                            False
# 138                          False                            False
# 143                            NaN                              NaN
# 145                          False                            False
# 149                          False                            False
# 152                            NaN                              NaN
# 164                            NaN                              NaN
# 168                          False                            False
# 172                          False                            False
# 177                          False                            False
# 186                            NaN                              NaN
# 189                          False                            False
# 194                            NaN                              NaN
# 197                          False                            False
# 208                          False                            False
# 209                            NaN                              NaN
# 221                            NaN                              NaN
# 224                            NaN                              NaN
# 230                          False                            False
# 233                            NaN                              NaN
# 237                            NaN                              NaN
# 239                          False                            False
# 242                          False                            False
# 243                          False                            False
# 245                            NaN                              NaN
# 249                          False                            False
# 251                          False                            False
# 259                          False                            False
# 262                            NaN                              NaN
# 263                          False                            False
# 278                          False                            False
#
#     other types of agreement  \
# 0                      False
# 14                     False
# 25                       NaN
# 31                     False
# 41                      True
# 42                     False
# 44                       NaN
# 50                     False
# 60                      True
# 61                     False
# 64                       NaN
# 71                     False
# 74                     False
# 80                       NaN
# 81                     False
# 86                       NaN
# 93                     False
# 94                     False
# 95                       NaN
# 98                     False
# 100                     True
# 101                    False
# 108                    False
# 109                      NaN
# 118                      NaN
# 119                      NaN
# 125                      NaN
# 128                      NaN
# 130                      NaN
# 132                    False
# 138                    False
# 143                      NaN
# 145                    False
# 149                    False
# 152                      NaN
# 164                      NaN
# 168                    False
# 172                    False
# 177                    False
# 186                      NaN
# 189                    False
# 194                      NaN
# 197                    False
# 208                    False
# 209                      NaN
# 221                      NaN
# 224                      NaN
# 230                    False
# 233                      NaN
# 237                      NaN
# 239                    False
# 242                    False
# 243                    False
# 245                      NaN
# 249                    False
# 251                     True
# 259                    False
# 262                      NaN
# 263                    False
# 278                    False
#
#                    HB 1932 affiliated German firm name  \
# 0                                                  NaN
# 14                                                 NaN
# 25   [Bayerische Mineral-Industrie Aktiengesellschaft]
# 31                                                 NaN
# 41                                                 NaN
# 42                                                 NaN
# 44                                                 NaN
# 50                                                 NaN
# 60      [Dynamit-Act.-Ges. vormals Alfred Nobel & Co.]
# 61                          [Kodak Aktiengesellschaft]
# 64                   [Ch. Eitingon Aktiengesellschaft]
# 71                                                 NaN
# 74             [Ford Motor Company Aktiengesellschaft]
# 80                                                 NaN
# 81   [Adam Opel Aktiengesellschaft, Eduard Winter A...
# 86                                                 NaN
# 93                                                 NaN
# 94                                                 NaN
# 95                                                 NaN
# 98                                                 NaN
# 100  [Allgemeine Elektricitäts-Gesellschaft, Kohlen...
# 101                                                NaN
# 108  [C. Lorenz Aktiengesellschaft, Mix & Genest Ak...
# 109                                                NaN
# 118                                                NaN
# 119                                                NaN
# 125      [Metro-Goldwyn-Mayer Film Aktiengesellschaft]
# 128        [Norddeutsche Mineralöl-Aktiengesellschaft]
# 130                                                NaN
# 132                                                NaN
# 138                                                NaN
# 143                                                NaN
# 145                                                NaN
# 149                                                NaN
# 152                [Paramount Film Aktiengesellsehaft]
# 164                                                NaN
# 168  [Torpedo-Fahrräder u. Schreibmaschinen, Weilwe...
# 172                        [Ritter Aktiengesellschaft]
# 177                                                NaN
# 186                                                NaN
# 189                    [Deutsche Vacuum Oel Akt.-Ges.]
# 194                                                NaN
# 197  [Deutsch-Amerikanische Petroleum-Ges., Mineral...
# 208                                                NaN
# 209                                                NaN
# 221                                                NaN
# 224                                                NaN
# 230                                                NaN
# 233                         [Pfaudler-Werke Akt.-Ges.]
# 237                                                NaN
# 239                                                NaN
# 242  [Dulv Aktiengesellschaft, Vereinigte Riegel- u...
# 243                                                NaN
# 245  [Europäische Titeflex Metallschlauch-Aktienges...
# 249             [Deutsche Fox-Film Aktiengesellschaft]
# 251  [Mercedes Büromaschinen-Werke Aktiengesellscha...
# 259                                                NaN
# 262                                                NaN
# 263                                                NaN
# 278                                                NaN
#
#                    HB 1934 affiliated German firm name
# 0                                                  NaN
# 14                                                 NaN
# 25   [Bayerische Mineral-Industrie Aktiengesellscha...
# 31                                                 NaN
# 41                                                 NaN
# 42                                                 NaN
# 44                                                 NaN
# 50   [W. A. Schölten Stärke- und Syrup-Fabriken Akt...
# 60   [Dynamit-Actien-Gesellschaft vormals Alfred No...
# 61                                                 NaN
# 64                  [Ch. Eitingon Aktiengesellschaft.]
# 71                                                 NaN
# 74           [Ford Motor Company Aktiengesellschaft. ]
# 80                                                 NaN
# 81                     [Adam Opel Aktiengesellschaft.]
# 86                                                 NaN
# 93                                                 NaN
# 94                                                 NaN
# 95                                                 NaN
# 98                                                 NaN
# 100           [Allgemeine Elektricitäts-Gesellschaft.]
# 101                                                NaN
# 108  [Mix & Genest Aktiengesellschaft. , C. Lorenz ...
# 109                                                NaN
# 118                                                NaN
# 119                                                NaN
# 125                                                NaN
# 128                                                NaN
# 130                                                NaN
# 132                                                NaN
# 138                                                NaN
# 143                                                NaN
# 145                                                NaN
# 149                                                NaN
# 152               [Paramount Film Aktiengesellschaft.]
# 164                                                NaN
# 168                                                NaN
# 172                       [Ritter Aktiengesellschaft.]
# 177                                                NaN
# 186                                                NaN
# 189                                                NaN
# 194                                                NaN
# 197  [Mineraloel-Raffinerie vorm. August Korff., De...
# 208                                                NaN
# 209  [Deutsche Babcock & Wilcox-Dampfkessel-Werke, ...
# 221                                                NaN
# 224                                                NaN
# 230                                                NaN
# 233                                                NaN
# 237                                                NaN
# 239                                                NaN
# 242                                                NaN
# 243                                                NaN
# 245  [Europäische Titeflex Metallschlauch-Aktienges...
# 249                                                NaN
# 251  [Mercedes Büromaschinen-Werke Aktiengesellscha...
# 259                                                NaN
# 262                                                NaN
# 263                                                NaN
# 278                                                NaN
#
# [60 rows x 44 columns]

# %%
tfr500_moodys32_moodys34_tenenbaum_hb32_hb34[((~tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['in Moodys 32']) &
                                        (~tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['in Moodys 34']) & 
                                        (~tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['in HB 32']) &
                                        (~tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['in HB 34'])) & 
                                        (tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['in TFR-500'])]
# Out:
#                           Master US firm name  in TFR-500  in Moodys 32  \
# 4    American -Austrian Magnesite Corporation        True         False
# 8                   American Cyanamid Company        True         False
# 9      American Foreign Insurance Association        True         False
# 13           American Nickel Alloy Mfg. Corp.        True         False
# 16    American-Austrian Magnesite Corporation        True         False
# ..                                        ...         ...           ...
# 270                        Waterman Steamship        True         False
# 271       Western Electric Export Corporation        True         False
# 272                      Westhold Corporation        True         False
# 274             William R. Warner & Co., Inc.        True         False
# 276                       Witroth Corporation        True         False
#
#      in Moodys 34  in Tenenbaum  in HB 32  in HB 34  \
# 4           False         False     False     False
# 8           False         False     False     False
# 9           False         False     False     False
# 13          False         False     False     False
# 16          False         False     False     False
# ..            ...           ...       ...       ...
# 270         False         False     False     False
# 271         False         False     False     False
# 272         False         False     False     False
# 274         False         False     False     False
# 276         False         False     False     False
#
#                                affiliated German firms type_Partnership  \
# 4    [Deutsche Heraklith A.G., Deutsche Heraklith A...            False
# 8                        [Farsals-Gesellschaft m.b.H.]            False
# 9    [Great American Insurance Co. - Home Insurance...            False
# 13   [Cosmo Montangesellschaft fuer metallurgische ...            False
# 16                                  [Alpenminen A. G.]            False
# ..                                                 ...              ...
# 270     [Waterman Linien (Vertretung Bremen) G.m.b.H.]            False
# 271                        [Western Electric G.m.b.H.]            False
# 272          [Ota Schlesische Schurwerke Ottmuth A.G.]            False
# 274  [Godecke & Co. Chemische Fabrik A.G., Godecke ...            False
# 276    [Oppelener Lagerhaus Gesellschaft, Ostrhederei]            False
#
#     type_branch  ... mentions a subsidiary mentions stock ownership  \
# 4         False  ...                   NaN                      NaN
# 8         False  ...                   NaN                      NaN
# 9          True  ...                   NaN                      NaN
# 13        False  ...                   NaN                      NaN
# 16        False  ...                   NaN                      NaN
# ..          ...  ...                   ...                      ...
# 270       False  ...                   NaN                      NaN
# 271       False  ...                   NaN                      NaN
# 272       False  ...                   NaN                      NaN
# 274       False  ...                   NaN                      NaN
# 276       False  ...                   NaN                      NaN
#
#     subsidiary is AG subsidiary is GmbH mentions an affilated company  \
# 4                NaN                NaN                           NaN
# 8                NaN                NaN                           NaN
# 9                NaN                NaN                           NaN
# 13               NaN                NaN                           NaN
# 16               NaN                NaN                           NaN
# ..               ...                ...                           ...
# 270              NaN                NaN                           NaN
# 271              NaN                NaN                           NaN
# 272              NaN                NaN                           NaN
# 274              NaN                NaN                           NaN
# 276              NaN                NaN                           NaN
#
#     mentions a plant/office/branch is a subsidiary of a German firm  \
# 4                              NaN                              NaN
# 8                              NaN                              NaN
# 9                              NaN                              NaN
# 13                             NaN                              NaN
# 16                             NaN                              NaN
# ..                             ...                              ...
# 270                            NaN                              NaN
# 271                            NaN                              NaN
# 272                            NaN                              NaN
# 274                            NaN                              NaN
# 276                            NaN                              NaN
#
#     other types of agreement HB 1932 affiliated German firm name  \
# 4                        NaN                                 NaN
# 8                        NaN                                 NaN
# 9                        NaN                                 NaN
# 13                       NaN                                 NaN
# 16                       NaN                                 NaN
# ..                       ...                                 ...
# 270                      NaN                                 NaN
# 271                      NaN                                 NaN
# 272                      NaN                                 NaN
# 274                      NaN                                 NaN
# 276                      NaN                                 NaN
#
#     HB 1934 affiliated German firm name
# 4                                   NaN
# 8                                   NaN
# 9                                   NaN
# 13                                  NaN
# 16                                  NaN
# ..                                  ...
# 270                                 NaN
# 271                                 NaN
# 272                                 NaN
# 274                                 NaN
# 276                                 NaN
#
# [111 rows x 44 columns]

# %%
tfr500_moodys32_moodys34_tenenbaum_hb32_hb34[((tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['in Moodys 32']) |
                                        (tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['in Moodys 34']) | 
                                        (tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['in HB 32']) |
                                        (tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['in HB 34'])) & 
                                        (tfr500_moodys32_moodys34_tenenbaum_hb32_hb34['in Tenenbaum'])]
# Out:
#                                    Master US firm name  in TFR-500  \
# 0                 Addressograph-Multigraph Corporation        True
# 10                       American I. G. Chemical Corp.       False
# 14   American Radiator & Standard Sanitary Corporation        True
# 15                      American Ship & Commerce Corp.       False
# 31                    Burroughs Adding Machine Company        True
# 41                          Chicago Pneumatic Tool Co.        True
# 42                          Colgate-Palmolive-Peet Co.        True
# 50                      Corn Products Refining company        True
# 60                 E.I. du Pont de Nemours and Company        True
# 61                               Eastman Kodak Company        True
# 71                                 F. W. Woolworth Co.        True
# 74                                  Ford Motor Company        True
# 79         General American Transportation Corporation       False
# 81    General Motors Corporation (Overseas Operations)        True
# 93                            Hugo Stinnes Corporation        True
# 94                       Hugo Stinnes Industries, Inc.        True
# 98                International Business Machine Corp.        True
# 100        International General Electric Company Inc.        True
# 101                    International Harvester Company        True
# 108        International Telephone and Telegraph Corp.        True
# 114                            Julius Kayser & Company       False
# 121                    Libbey-Owens-Ford Glass Company       False
# 132                      Mergenthaler Linotype Company        True
# 138                              National Lead Company        True
# 145                                     Norton Company        True
# 149                              Otis Elevator Company        True
# 150  Pan American Foreign Corporation (Controlled b...       False
# 168                                Remington Rand Inc.        True
# 172  Ritter Company, Inc. (Formerly Ritter Dental M...        True
# 177                     Royal Typewriter Company, Inc.        True
# 187                      Silesian-American Corporation       False
# 189                    Socony-Vacuum Oil Company, Inc.        True
# 197                  Standard Oil Company (New Jersey)        True
# 208                      The Atlantic Refining Company        True
# 219                 The Goodyear Tire & Rubber Company       False
# 230                 The National Cash Register Company        True
# 238                  The Timken Roller Bearing Company       False
# 239                             The Torrington Company        True
# 242             The Yale & Towne Manufacturing Company        True
# 243                      Tide Water Associated Oil Co.        True
# 249                   Twentieth Century-Fox Film Corp.        True
# 251                   Underwood Elliott Fisher Company        True
# 259        United States Hoffman Machinery Corporation        True
# 263                        Universal Picture Co., Inc.        True
# 277                            Wm. Wrigley Jr. Company       False
# 278               Worthington Pump and Machinery Corp.        True
#
#      in Moodys 32  in Moodys 34  in Tenenbaum  in HB 32  in HB 34  \
# 0            True          True          True     False     False
# 10          False          True          True     False     False
# 14           True          True          True     False     False
# 15          False          True          True     False     False
# 31           True          True          True     False     False
# 41           True          True          True     False     False
# 42           True          True          True     False     False
# 50          False         False          True     False      True
# 60           True          True          True      True      True
# 61           True          True          True      True     False
# 71           True          True          True     False     False
# 74           True          True          True      True      True
# 79          False          True          True     False     False
# 81           True          True          True      True      True
# 93           True          True          True     False     False
# 94           True          True          True     False     False
# 98           True         False          True     False     False
# 100          True          True          True      True      True
# 101          True          True          True     False     False
# 108         False         False          True      True      True
# 114          True          True          True     False     False
# 121          True          True          True     False     False
# 132          True          True          True     False     False
# 138          True          True          True     False     False
# 145          True          True          True     False     False
# 149         False          True          True     False     False
# 150          True          True          True     False     False
# 168          True          True          True      True     False
# 172          True          True          True      True      True
# 177          True          True          True     False     False
# 187          True          True          True     False     False
# 189         False         False          True      True     False
# 197          True          True          True      True      True
# 208         False          True          True     False     False
# 219         False          True          True      True      True
# 230         False          True          True     False     False
# 238          True          True          True     False     False
# 239          True          True          True     False     False
# 242          True          True          True      True     False
# 243         False          True          True     False     False
# 249          True          True          True      True     False
# 251          True          True          True      True      True
# 259         False          True          True     False     False
# 263         False          True          True     False     False
# 277         False          True          True      True      True
# 278          True          True          True     False     False
#
#                                affiliated German firms type_Partnership  \
# 0                  [Addressograph-Multigraph G.m.b.H.]            False
# 10                                                 NaN              NaN
# 14            [Nationale Radiator Gesellschaft m.b.H.]            False
# 15                                                 NaN              NaN
# 31           [Deutsche Burroughs Rechenmaschinen A.G.]            False
# 41   [Internationale Pressluft und Elektricitats Ge...            False
# 42                [Palmolive-Binder & Ketals G.m.b.H.]            False
# 50   [Aktien-Malsfabrik Landsburg, A. G., Convertga...            False
# 60                           [Duco Aktiengesellschaft]            False
# 61                          [Kodak Aktiengesellschaft]            False
# 71          [F. W. Woolworth Co., F. W. Woolworth Co.]            False
# 74                  [Ford Werke A.G., Ford Werke A.G.]            False
# 79                                                 NaN              NaN
# 81   [Adam Opel Aktiengsellschaft, Frigidaire G.m.b...            False
# 93   [Eisenlager G.m.b.H., Freidreichstrasse, 12, G...            False
# 94   [Anker Kohlen & Brikettwerke G.m.b.H., Artus H...            False
# 98   [Deutsche Hollerith Maschinen Gesellschaft, m....            False
# 100             [Osram G.m.b.H. Kommanditgesellschaft]             True
# 101          [International Harvester Company, m.b.H.]            False
# 108  [Baruta Import and Export, GmbH, Baruta Import...            False
# 114                                                NaN              NaN
# 121                                                NaN              NaN
# 132  [Linotype, G.m.b.H., Mergenthaler Setzmaschine...            False
# 138                  [Zinnwerke Wilheimsburg G.m.b.H.]            False
# 145             [Deutsche Norton-Gesellschaft, m.b.H.]            False
# 149                       [Otis Aufzugswerke G.m.b.H.]            False
# 150                                                NaN              NaN
# 168  [Jahresuhren Fabrik G.m.b.H., Kardex A.G., Kar...            False
# 172                                     [Ritter, A.G.]            False
# 177  [Orga Akt. Ges., Royal Schreihmaschinen, G.m.b...            False
# 187                                                NaN              NaN
# 189  [Deutsche Vacuum Oel A.G., Erdolbergbau A.G., ...            False
# 197  [Allgemeine Oel-Handels-Gesellschaft mit besch...            False
# 208  [Allgemeine Oel-Handels, GmbH. (Oelhag), The A...            False
# 219                                                NaN              NaN
# 230        [National-Krupp Registrier-Kassen G.m.b.H.]            False
# 238                                                NaN              NaN
# 239                           [Metallkentor, G.m.b.H.]            False
# 242  [Brankaer Eisenwerke, Damm & Ladwig Kommandit ...            False
# 243         [Hamburg-Amerikanische Mineralol-G.m.b.H.]            False
# 249  [Deutsche-Fox Film A.G., Fox Tonende Wochenschau]            False
# 251  [Adrema Maschinenebau G.m.b.H., Deutsche Under...            False
# 259       [Hoffman Bugelmaschinen Gesellschaft m.b.H.]            False
# 263                    [Deutsche Universal Film, A.G.]            False
# 277                                                NaN              NaN
# 278         [Deutsche Worthington Gesellschaft m.b.H.]            False
#
#     type_branch  ... mentions a subsidiary mentions stock ownership  \
# 0         False  ...                  True                    False
# 10          NaN  ...                 False                    False
# 14        False  ...                  True                    False
# 15          NaN  ...                 False                     True
# 31        False  ...                  True                    False
# 41        False  ...                  True                    False
# 42        False  ...                  True                    False
# 50        False  ...                  True                    False
# 60        False  ...                  True                     True
# 61        False  ...                  True                    False
# 71         True  ...                  True                    False
# 74        False  ...                  True                    False
# 79          NaN  ...                  True                    False
# 81        False  ...                  True                     True
# 93        False  ...                 False                    False
# 94         True  ...                  True                     True
# 98        False  ...                 False                    False
# 100       False  ...                  True                     True
# 101       False  ...                  True                    False
# 108       False  ...                  True                     True
# 114         NaN  ...                 False                    False
# 121         NaN  ...                  True                     True
# 132       False  ...                  True                    False
# 138       False  ...                  True                    False
# 145       False  ...                  True                    False
# 149       False  ...                  True                    False
# 150         NaN  ...                  True                    False
# 168       False  ...                  True                    False
# 172       False  ...                  True                    False
# 177       False  ...                  True                    False
# 187         NaN  ...                 False                    False
# 189       False  ...                  True                    False
# 197       False  ...                  True                    False
# 208       False  ...                  True                    False
# 219         NaN  ...                  True                    False
# 230       False  ...                  True                    False
# 238         NaN  ...                  True                    False
# 239       False  ...                  True                    False
# 242       False  ...                  True                    False
# 243       False  ...                  True                    False
# 249       False  ...                  True                    False
# 251       False  ...                  True                     True
# 259       False  ...                  True                    False
# 263       False  ...                  True                    False
# 277         NaN  ...                 False                    False
# 278       False  ...                  True                    False
#
#     subsidiary is AG subsidiary is GmbH mentions an affilated company  \
# 0              False               True                         False
# 10             False              False                         False
# 14             False               True                         False
# 15             False              False                         False
# 31              True              False                         False
# 41              True               True                         False
# 42             False               True                         False
# 50              True               True                         False
# 60              True              False                         False
# 61              True              False                         False
# 71             False               True                         False
# 74              True              False                         False
# 79              True              False                         False
# 81              True               True                         False
# 93             False              False                         False
# 94              True               True                         False
# 98             False              False                         False
# 100             True              False                         False
# 101            False               True                         False
# 108             True               True                         False
# 114            False              False                         False
# 121             True              False                         False
# 132            False               True                         False
# 138            False               True                         False
# 145            False               True                         False
# 149            False               True                         False
# 150             True              False                         False
# 168            False               True                         False
# 172             True              False                         False
# 177            False               True                         False
# 187            False              False                         False
# 189             True              False                         False
# 197             True              False                         False
# 208            False               True                         False
# 219             True              False                         False
# 230            False               True                         False
# 238            False               True                         False
# 239            False               True                         False
# 242            False              False                         False
# 243            False               True                         False
# 249             True              False                         False
# 251             True              False                         False
# 259            False               True                         False
# 263             True              False                         False
# 277             True              False                         False
# 278            False               True                         False
#
#     mentions a plant/office/branch is a subsidiary of a German firm  \
# 0                            False                            False
# 10                           False                             True
# 14                           False                            False
# 15                           False                            False
# 31                           False                            False
# 41                           False                            False
# 42                           False                            False
# 50                           False                            False
# 60                           False                            False
# 61                           False                            False
# 71                           False                            False
# 74                            True                            False
# 79                           False                            False
# 81                           False                            False
# 93                           False                            False
# 94                           False                            False
# 98                            True                            False
# 100                          False                            False
# 101                           True                            False
# 108                          False                            False
# 114                          False                            False
# 121                          False                            False
# 132                          False                            False
# 138                          False                            False
# 145                          False                            False
# 149                          False                            False
# 150                          False                            False
# 168                          False                            False
# 172                          False                            False
# 177                          False                            False
# 187                          False                            False
# 189                          False                            False
# 197                          False                            False
# 208                          False                            False
# 219                          False                            False
# 230                          False                            False
# 238                          False                            False
# 239                          False                            False
# 242                          False                            False
# 243                          False                            False
# 249                          False                            False
# 251                          False                            False
# 259                          False                            False
# 263                          False                            False
# 277                          False                            False
# 278                          False                            False
#
#     other types of agreement  \
# 0                      False
# 10                     False
# 14                     False
# 15                     False
# 31                     False
# 41                      True
# 42                     False
# 50                     False
# 60                      True
# 61                     False
# 71                     False
# 74                     False
# 79                     False
# 81                     False
# 93                     False
# 94                     False
# 98                     False
# 100                     True
# 101                    False
# 108                    False
# 114                    False
# 121                    False
# 132                    False
# 138                    False
# 145                    False
# 149                    False
# 150                    False
# 168                    False
# 172                    False
# 177                    False
# 187                    False
# 189                    False
# 197                    False
# 208                    False
# 219                    False
# 230                    False
# 238                    False
# 239                    False
# 242                    False
# 243                    False
# 249                    False
# 251                     True
# 259                    False
# 263                    False
# 277                    False
# 278                    False
#
#                    HB 1932 affiliated German firm name  \
# 0                                                  NaN
# 10                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 31                                                 NaN
# 41                                                 NaN
# 42                                                 NaN
# 50                                                 NaN
# 60      [Dynamit-Act.-Ges. vormals Alfred Nobel & Co.]
# 61                          [Kodak Aktiengesellschaft]
# 71                                                 NaN
# 74             [Ford Motor Company Aktiengesellschaft]
# 79                                                 NaN
# 81   [Adam Opel Aktiengesellschaft, Eduard Winter A...
# 93                                                 NaN
# 94                                                 NaN
# 98                                                 NaN
# 100  [Allgemeine Elektricitäts-Gesellschaft, Kohlen...
# 101                                                NaN
# 108  [C. Lorenz Aktiengesellschaft, Mix & Genest Ak...
# 114                                                NaN
# 121                                                NaN
# 132                                                NaN
# 138                                                NaN
# 145                                                NaN
# 149                                                NaN
# 150                                                NaN
# 168  [Torpedo-Fahrräder u. Schreibmaschinen, Weilwe...
# 172                        [Ritter Aktiengesellschaft]
# 177                                                NaN
# 187                                                NaN
# 189                    [Deutsche Vacuum Oel Akt.-Ges.]
# 197  [Deutsch-Amerikanische Petroleum-Ges., Mineral...
# 208                                                NaN
# 219  [The Goodyear Tire & Rubber Co. Aktiengesellsc...
# 230                                                NaN
# 238                                                NaN
# 239                                                NaN
# 242  [Dulv Aktiengesellschaft, Vereinigte Riegel- u...
# 243                                                NaN
# 249             [Deutsche Fox-Film Aktiengesellschaft]
# 251  [Mercedes Büromaschinen-Werke Aktiengesellscha...
# 259                                                NaN
# 263                                                NaN
# 277                       [Wrigley Aktiengesellschaft]
# 278                                                NaN
#
#                    HB 1934 affiliated German firm name
# 0                                                  NaN
# 10                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 31                                                 NaN
# 41                                                 NaN
# 42                                                 NaN
# 50   [W. A. Schölten Stärke- und Syrup-Fabriken Akt...
# 60   [Dynamit-Actien-Gesellschaft vormals Alfred No...
# 61                                                 NaN
# 71                                                 NaN
# 74           [Ford Motor Company Aktiengesellschaft. ]
# 79                                                 NaN
# 81                     [Adam Opel Aktiengesellschaft.]
# 93                                                 NaN
# 94                                                 NaN
# 98                                                 NaN
# 100           [Allgemeine Elektricitäts-Gesellschaft.]
# 101                                                NaN
# 108  [Mix & Genest Aktiengesellschaft. , C. Lorenz ...
# 114                                                NaN
# 121                                                NaN
# 132                                                NaN
# 138                                                NaN
# 145                                                NaN
# 149                                                NaN
# 150                                                NaN
# 168                                                NaN
# 172                       [Ritter Aktiengesellschaft.]
# 177                                                NaN
# 187                                                NaN
# 189                                                NaN
# 197  [Mineraloel-Raffinerie vorm. August Korff., De...
# 208                                                NaN
# 219  [The Goodyear Tire & Rubber Co. Aktiengesellsc...
# 230                                                NaN
# 238                                                NaN
# 239                                                NaN
# 242                                                NaN
# 243                                                NaN
# 249                                                NaN
# 251  [Mercedes Büromaschinen-Werke Aktiengesellscha...
# 259                                                NaN
# 263                                                NaN
# 277                      [Wrigley Aktiengesellschaft.]
# 278                                                NaN
#
# [46 rows x 44 columns]

# %%
firms_unique = tfr500_moodys32_moodys34_tenenbaum_hb32_hb34.groupby('Master US firm name').first()

firms_unique[['in TFR-500', 'in Moodys 32', 'in Moodys 34', 'in Tenenbaum', 'in HB 32', 'in HB 34']].sum()
# Out:
# in TFR-500      171
# in Moodys 32     79
# in Moodys 34    100
# in Tenenbaum     89
# in HB 32         34
# in HB 34         25
# dtype: int64

# %% [markdown]
# ### Moody's

# %%
bool_cols = ['mentions a subsidiary', 
             'mentions stock ownership',
             'mentions an affilated company',
             'mentions a plant/office/branch', 
             'is a subsidiary of a German firm',
             'other types of agreement']

# %%
moodys32_counts = moodys32_parent_list[bool_cols].sum().to_frame(name="Moody's 32")
moodys34_counts = moodys34_parent_list[bool_cols].sum().to_frame(name="Moody's 34")

# %%
moodys_merged = moodys32_parent_list.merge(moodys34_parent_list, on='Master US firm name', how='outer', suffixes=['_moodys32', '_moodys34'])

for col in bool_cols:
    moodys_merged[col] = (
        moodys_merged[f"{col}_moodys32"]
        .fillna(False) | moodys_merged[f"{col}_moodys34"].fillna(False)
    )
    # # If both are NaN, result should stay NaN
    # both_na = moodys_merged[f"{col}_moodys32"].isna() & moodys_merged[f"{col}_moodys34"].isna()
    # moodys_merged.loc[both_na, col] = pd.NA

# Optional: drop the suffixed columns
moodys_merged.drop(columns=[f"{col}_moodys32" for col in bool_cols] + [f"{col}_moodys34" for col in bool_cols], inplace=True)
# Out:
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_90375/4082947527.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(False) | moodys_merged[f"{col}_moodys34"].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_90375/4082947527.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(False) | moodys_merged[f"{col}_moodys34"].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_90375/4082947527.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(False) | moodys_merged[f"{col}_moodys34"].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_90375/4082947527.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(False) | moodys_merged[f"{col}_moodys34"].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_90375/4082947527.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(False) | moodys_merged[f"{col}_moodys34"].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_90375/4082947527.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(False) | moodys_merged[f"{col}_moodys34"].fillna(False)

# %%
moodys_merged_counts = moodys_merged[bool_cols].sum().to_frame(name="merged")

# %%
moodys_counts = pd.concat([moodys32_counts, moodys34_counts, moodys_merged_counts], axis=1)
moodys_counts.loc['Total'] = [
    moodys32_parent_list.shape[0],
    moodys34_parent_list.shape[0],
    moodys_merged.shape[0]
]
moodys_counts.to_latex('output/table/moodys_count.tex')

# %% [markdown]
# ### print table

# %%
print('in TFR: ' + str(parent_large_table[parent_large_table['in TFR-500']].shape[0]))
print('in Tenenbaum: ' + str(parent_large_table[parent_large_table['in Tenenbaum']].shape[0]))
print('in TFR or Tenenbaum: ' + str(parent_large_table[(parent_large_table['in TFR-500']) | (parent_large_table['in Tenenbaum'])].shape[0]))
# Out:
# in TFR: 171
# in Tenenbaum: 89
# in TFR or Tenenbaum: 213

# %%
print('in HB 32: ' + str(parent_large_table[(parent_large_table['in HB 32'])].shape[0]))
print('in HB 32 and TFR: ' + str(parent_large_table[(parent_large_table['in HB 32']) & (parent_large_table['in TFR-500'])].shape[0]))
print('in HB 32 and Tenenbaum: ' + str(parent_large_table[(parent_large_table['in HB 32']) & (parent_large_table['in Tenenbaum'])].shape[0]))
print('in HB 32 and in TFR or Tenenbaum: ' + str(parent_large_table[(parent_large_table['in HB 32']) & ((parent_large_table['in TFR-500']) | (parent_large_table['in Tenenbaum']))].shape[0]))
print('-----------------')
print('in HB 34: ' + str(parent_large_table[(parent_large_table['in HB 34'])].shape[0]))
print('in HB 34 and TFR: ' + str(parent_large_table[(parent_large_table['in HB 34']) & (parent_large_table['in TFR-500'])].shape[0]))
print('in HB 34 and Tenenbaum: ' + str(parent_large_table[(parent_large_table['in HB 34']) & (parent_large_table['in Tenenbaum'])].shape[0]))
print('in HB 34 and in TFR or Tenenbaum: ' + str(parent_large_table[(parent_large_table['in HB 34']) & ((parent_large_table['in TFR-500']) | (parent_large_table['in Tenenbaum']))].shape[0]))
print('-----------------')
print('in HB 34 or 32: ' + str(parent_large_table[((parent_large_table['in HB 32']) | (parent_large_table['in HB 34']))].shape[0]))
print('in HB 34 or 32 and TFR: ' + str(parent_large_table[((parent_large_table['in HB 32']) | (parent_large_table['in HB 34'])) & (parent_large_table['in TFR-500'])].shape[0]))
print('in HB 34 or 32 and Tenenbaum: ' + str(parent_large_table[((parent_large_table['in HB 32']) | (parent_large_table['in HB 34'])) & (parent_large_table['in Tenenbaum'])].shape[0]))
print('in HB 34 or 32 and in TFR or Tenenbaum: ' + str(parent_large_table[((parent_large_table['in HB 32']) | (parent_large_table['in HB 34'])) & ((parent_large_table['in TFR-500']) | (parent_large_table['in Tenenbaum']))].shape[0]))
# Out:
# in HB 32: 34
# in HB 32 and TFR: 20
# in HB 32 and Tenenbaum: 15
# in HB 32 and in TFR or Tenenbaum: 22
# -----------------
# in HB 34: 25
# in HB 34 and TFR: 14
# in HB 34 and Tenenbaum: 11
# in HB 34 and in TFR or Tenenbaum: 16
# -----------------
# in HB 34 or 32: 38
# in HB 34 or 32 and TFR: 22
# in HB 34 or 32 and Tenenbaum: 16
# in HB 34 or 32 and in TFR or Tenenbaum: 24

# %%
print('in HB GmbH: ' + str(parent_large_table[(parent_large_table['in HB GmbH'])].shape[0]))
print('in HB GmbH and TFR: ' + str(parent_large_table[(parent_large_table['in HB GmbH']) & (parent_large_table['in TFR-500'])].shape[0]))
print('in HB GmbH and Tenenbaum: ' + str(parent_large_table[(parent_large_table['in HB GmbH']) & (parent_large_table['in Tenenbaum'])].shape[0]))
print('in HB GmbH and in TFR or Tenenbaum: ' + str(parent_large_table[(parent_large_table['in HB GmbH']) & ((parent_large_table['in TFR-500']) | (parent_large_table['in Tenenbaum']))].shape[0]))
# Out:
# in HB GmbH: 35
# in HB GmbH and TFR: 15
# in HB GmbH and Tenenbaum: 8
# in HB GmbH and in TFR or Tenenbaum: 16

# %%
print('in Moodys 32: ' + str(parent_large_table[(parent_large_table['in Moodys 32'])].shape[0]))
print('in Moodys 32 and TFR: ' + str(parent_large_table[(parent_large_table['in Moodys 32']) & (parent_large_table['in TFR-500'])].shape[0]))
print('in Moodys 32 and Tenenbaum: ' + str(parent_large_table[(parent_large_table['in Moodys 32']) & (parent_large_table['in Tenenbaum'])].shape[0]))
print('in Moodys 32 and in TFR or Tenenbaum: ' + str(parent_large_table[(parent_large_table['in Moodys 32']) & ((parent_large_table['in TFR-500']) | (parent_large_table['in Tenenbaum']))].shape[0]))
print('-----------------')
print('in Moodys 34: ' + str(parent_large_table[(parent_large_table['in Moodys 34'])].shape[0]))
print('in Moodys 34 and TFR: ' + str(parent_large_table[(parent_large_table['in Moodys 34']) & (parent_large_table['in TFR-500'])].shape[0]))
print('in Moodys 34 and Tenenbaum: ' + str(parent_large_table[(parent_large_table['in Moodys 34']) & (parent_large_table['in Tenenbaum'])].shape[0]))
print('in Moodys 34 and in TFR or Tenenbaum: ' + str(parent_large_table[(parent_large_table['in Moodys 34']) & ((parent_large_table['in TFR-500']) | (parent_large_table['in Tenenbaum']))].shape[0]))
print('-----------------')
print('in Moodys 34 or 32: ' + str(parent_large_table[((parent_large_table['in Moodys 32']) | (parent_large_table['in Moodys 34']))].shape[0]))
print('in Moodys 34 or 32 and TFR: ' + str(parent_large_table[((parent_large_table['in Moodys 32']) | (parent_large_table['in Moodys 34'])) & (parent_large_table['in TFR-500'])].shape[0]))
print('in Moodys 34 or 32 and Tenenbaum: ' + str(parent_large_table[((parent_large_table['in Moodys 32']) | (parent_large_table['in Moodys 34'])) & (parent_large_table['in Tenenbaum'])].shape[0]))
print('in Moodys 34 or 32 and in TFR or Tenenbaum: ' + str(parent_large_table[((parent_large_table['in Moodys 32']) | (parent_large_table['in Moodys 34'])) & ((parent_large_table['in TFR-500']) | (parent_large_table['in Tenenbaum']))].shape[0]))
# Out:
# in Moodys 32: 79
# in Moodys 32 and TFR: 44
# in Moodys 32 and Tenenbaum: 32
# in Moodys 32 and in TFR or Tenenbaum: 49
# -----------------
# in Moodys 34: 100
# in Moodys 34 and TFR: 48
# in Moodys 34 and Tenenbaum: 42
# in Moodys 34 and in TFR or Tenenbaum: 58
# -----------------
# in Moodys 34 or 32: 116
# in Moodys 34 or 32 and TFR: 53
# in Moodys 34 or 32 and Tenenbaum: 43
# in Moodys 34 or 32 and in TFR or Tenenbaum: 63

# %%
all_identified = parent_large_table[(parent_large_table['in HB 32']) | (parent_large_table['in HB 34']) | 
                                    (parent_large_table['in Moodys 32']) | (parent_large_table['in Moodys 34']) | 
                                    (parent_large_table['in HB GmbH'])]

print('all identified: ' + str(all_identified.shape[0]))
print('all identified and in TFR-500: ' + str(all_identified[all_identified['in TFR-500']].shape[0]))
print('all identified and in Tenenbaum: ' + str(all_identified[all_identified['in Tenenbaum']].shape[0]))
print('all identified and in Tenenbaum: ' + str(all_identified[(all_identified['in TFR-500']) | (all_identified['in Tenenbaum'])].shape[0]))
# Out:
# all identified: 157
# all identified and in TFR-500: 68
# all identified and in Tenenbaum: 50
# all identified and in Tenenbaum: 79
