# %%
import pandas as pd
import gspread
from gspread_dataframe import set_with_dataframe
from oauth2client.service_account import ServiceAccountCredentials

# Auth
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('../gspread_creds.json', scope)
client = gspread.authorize(creds)

# %%
# Open the sheet
worksheet = client.open("Moodys 1934").worksheet("reviewed-expanded")

# Get all records as list of dicts
records = worksheet.get_all_records()

# Convert to DataFrame
moodys34 = pd.DataFrame(records)

bool_cols = ['mentions a subsidiary', 
             'mentions stock ownership',
             'subsidiary is AG',
             'subsidiary is GmbH',
             'mentions an affilated company',
             'mentions a plant/office/branch', 
             'is a subsidiary of a German firm',
             'other types of agreement']
moodys34[bool_cols] = moodys34[bool_cols].apply(lambda x: x == "TRUE")
moodys34['affiliated German firm name'] = moodys34['affiliated German firm name'].replace('NA', '')

# %%
moodys34
# Out:
#      page  block  line      x0       y0      x1       y1  \
# 0     176     25     5   74.65  410.171  524.00  421.870
# 1     176     25     5   74.65  410.171  524.00  421.870
# 2     305     74     1  305.30   75.673  524.20   86.974
# 3     351      5     1   77.50   98.241  165.40  105.170
# 4     375     34     4  303.10  117.600  525.20  131.500
# ..    ...    ...   ...     ...      ...     ...      ...
# 127  3377     27    73  225.85  446.732  370.85  457.033
# 128  3377     27    73  225.85  446.732  370.85  457.033
# 129  3377     27    73  225.85  446.732  370.85  457.033
# 130  3377     27    73  225.85  446.732  370.85  457.033
# 131  3377     27    73  225.85  446.732  370.85  457.033
#
#                                                   text keyword page_right  \
# 0    Together with Th. Goldschmidt of Essen, German...  German        176
# 1    Together with Th. Goldschmidt of Essen, German...  German        176
# 2    German subsidiary which are subject to exchang...  German        305
# 3                          German factory (not ourr.)   German        351
# 4    acquired all capital stock of Berlin A Co. and...  Berlin        375
# ..                                                 ...     ...        ...
# 127          of oil fields in Germany and at Mar. 10,   German       3377
# 128          of oil fields in Germany and at Mar. 10,   German       3377
# 129          of oil fields in Germany and at Mar. 10,   German       3377
# 130          of oil fields in Germany and at Mar. 10,   German       3377
# 131          of oil fields in Germany and at Mar. 10,   German       3377
#
#      ...                            Master German firm name  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...                                                ...
# 127  ...  Erdoelwerke Wathlingen, Wuerttembergische Mine...
# 128  ...            Nordeuropaeische Oelgesellschaft m.b.H.
# 129  ...                        Gewerkschaft Regina zu Caan
# 130  ...     Oldenburgische Oelausbeutungesellschaft m.b.H.
# 131  ...                         Harburger Bergbau G.m.b.H.
#
#                                         reviewed_notes mentions a subsidiary  \
# 0    with Th. Goldschmidt of Essen, Germany, organi...                 False
# 1    with Th. Goldschmidt of Essen, Germany, organi...                 False
# 2                                                                      False
# 3          German factory appears in the balance sheet                 False
# 4                              No subsidiary in German                 False
# ..                                                 ...                   ...
# 127  In description: Owns entire capital stock of f...                  True
# 128  In description: Owns entire capital stock of f...                  True
# 129  In description: Owns entire capital stock of f...                  True
# 130  In description: Owns entire capital stock of f...                  True
# 131  In description: Owns entire capital stock of f...                  True
#
#     mentions stock ownership subsidiary is AG subsidiary is GmbH  \
# 0                      False            False              False
# 1                      False            False              False
# 2                      False            False              False
# 3                      False            False              False
# 4                      False            False              False
# ..                       ...              ...                ...
# 127                    False            False               True
# 128                    False            False               True
# 129                    False            False               True
# 130                    False            False               True
# 131                    False            False               True
#
#     mentions an affilated company mentions a plant/office/branch  \
# 0                           False                          False
# 1                           False                          False
# 2                           False                          False
# 3                           False                           True
# 4                           False                          False
# ..                            ...                            ...
# 127                         False                          False
# 128                         False                          False
# 129                         False                          False
# 130                         False                          False
# 131                         False                          False
#
#      is a subsidiary of a German firm  other types of agreement
# 0                               False                     False
# 1                               False                     False
# 2                               False                     False
# 3                               False                     False
# 4                               False                     False
# ..                                ...                       ...
# 127                             False                     False
# 128                             False                     False
# 129                             False                     False
# 130                             False                     False
# 131                             False                     False
#
# [132 rows x 26 columns]

# %%
moodys34_to_csv = moodys34.rename(columns={'Master US firm name': 'US Company'})
moodys34_to_csv.to_csv('output/moodys34.csv', index=False)
