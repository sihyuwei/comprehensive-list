# %%
import pandas as pd
import gspread
from gspread_dataframe import set_with_dataframe
from oauth2client.service_account import ServiceAccountCredentials

# Auth
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('../gspread_creds.json', scope)
client = gspread.authorize(creds)

# %%
# Open the sheet
worksheet = client.open("Tenenbaum").worksheet("Sheet1 expanded")

# Get all records as list of dicts
records = worksheet.get_all_records()

# Convert to DataFrame
tenenbaum = pd.DataFrame(records)

bool_cols = ['mentions a subsidiary', 
             'mentions stock ownership',
             'affiliated company is AG',
             'affiliated company is GmbH',
             'mentions an affiliated company',
             'mentions a plant/office/branch', 
             'is a subsidiary of a German firm',
             'other types of agreement']
tenenbaum[bool_cols] = tenenbaum[bool_cols].apply(lambda x: x == "TRUE")

# %%
tenenbaum
# Out:
#                     US firm name  \
# 0             Ford Motor Company
# 1             Ford Motor Company
# 2     General Motors Corporation
# 3     General Motors Corporation
# 4     General Motors Corporation
# ..                           ...
# 139  Libbey-Owens-Ford Glass Co.
# 140  Libbey-Owens-Ford Glass Co.
# 141           The Norton Company
# 142             Amber Mines Inc.
# 143          F. W. Woolworth Co.
#
#                                   Master US firm name  \
# 0                                  Ford Motor Company
# 1                                  Ford Motor Company
# 2    General Motors Corporation (Overseas Operations)
# 3    General Motors Corporation (Overseas Operations)
# 4    General Motors Corporation (Overseas Operations)
# ..                                                ...
# 139                   Libbey-Owens-Ford Glass Company
# 140                   Libbey-Owens-Ford Glass Company
# 141                                    Norton Company
# 142                                  Amber Mines Inc.
# 143                               F. W. Woolworth Co.
#
#                            affiliated German firm name  \
# 0                                 Ford Motor Co. A. G.
# 1                       Credit A. G. für Fordfahrzeuge
# 2                                       Adam Opel A.G.
# 3                     Opel Automobilversicherungs A.G.
# 4                         Continentale Gummiwerke A.G.
# ..                                                 ...
# 139  Deutsche Libbey -Owens Gesellschaft für machin...
# 140                           Deutsche Tafelglas A. G.
# 141                           Deutsche Norton G.m.b.H.
# 142     Preussische Bergwerks- und Hutten Gesellschaft
# 143                       F. W. Woolworth Co. G.m.b.H.
#
#                                Master German firm name  \
# 0                                        Ford-Werke AG
# 1        Credit Aktiengesellschaft für Ford-Fahrzeuge.
# 2                         Adam Opel Aktiengesellschaft
# 3                      Opel Automobil Versicherungs AG
# 4                        Continentale Gummiwerke A.G.
# ..                                                 ...
# 139  Deutsche Libbey-Owens Gesellschaft für machine...
# 140    Deutsche Tafelglas Aktiengesellschaft (Detag).
# 141               Deutsche Norton-Gesellschaft, m.b.H.
# 142     Preussische Bergwerks- und Hutten Gesellschaft
# 143                                F. W. Woolworth Co.
#
#                                                  notes  mentions a subsidiary  \
# 0                                                                        True
# 1                                                                        True
# 2                                                                        True
# 3                                                                        True
# 4                                                                        True
# ..                                                 ...                    ...
# 139  The LIBBEY-OWENS-FORD GLASS Co. owns the Cie. ...                   True
# 140  The LIBBEY-OWENS-FORD GLASS Co. owns the Cie. ...                   True
# 141  The NORTON COMPANY (abrasives ) owns the Deuts...                   True
# 142  The PREUSSISCHE Bergwerks- UND HUTTEN GESELLSC...                  False
# 143  The F. W. WOOLWORTH Co. owns outright the F. W...                   True
#
#      mentions stock ownership  affiliated company is AG  \
# 0                       False                      True
# 1                       False                      True
# 2                        True                      True
# 3                        True                      True
# 4                        True                      True
# ..                        ...                       ...
# 139                      True                      True
# 140                      True                      True
# 141                     False                     False
# 142                     False                     False
# 143                     False                     False
#
#      affiliated company is GmbH  mentions an affiliated company  \
# 0                         False                           False
# 1                         False                           False
# 2                         False                           False
# 3                         False                           False
# 4                         False                           False
# ..                          ...                             ...
# 139                       False                           False
# 140                       False                           False
# 141                        True                           False
# 142                        True                           False
# 143                        True                           False
#
#      mentions a plant/office/branch  is a subsidiary of a German firm  \
# 0                              True                             False
# 1                              True                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
# ..                              ...                               ...
# 139                           False                             False
# 140                           False                             False
# 141                           False                             False
# 142                           False                              True
# 143                           False                             False
#
#      other types of agreement
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ..                        ...
# 139                     False
# 140                     False
# 141                     False
# 142                     False
# 143                     False
#
# [144 rows x 13 columns]

# %%
def assign_link_type(row):
    if row['mentions a subsidiary']:
        link_type = 'USO'
    elif row['mentions stock ownership']:
        link_type = 'USOP'
    elif row['mentions an affiliated company']:
        link_type = 'USC'
    elif row['other types of agreement']:
        link_type = 'USC'
    elif row['is a subsidiary of a German firm']:
        link_type = 'DEO'
    else:
        link_type = 'Others'

    return link_type

def assign_org_type(row):
    if row['affiliated company is AG']:
        org_type = 'AG'
    elif row['affiliated company is GmbH']:
        org_type = 'GmbH'
    else:
        org_type = 'Others'

    return org_type

tenenbaum['link_type'] = tenenbaum.apply(assign_link_type, axis=1)
tenenbaum['org_type'] = tenenbaum.apply(assign_org_type, axis=1)

# %%
tenenbaum_to_csv = tenenbaum.rename(columns={'Master US firm name': 'US Company', 
                                             'Master German firm name': 'German subsidiary',
                                             'US firm name': 'US firm (as in book)',
                                             'affiliated German firm name': 'Affiliated German firm (as in book)',
                                             'notes': 'Description'})
tenenbaum_to_csv = tenenbaum_to_csv[['German subsidiary', 'US Company', 'link_type', 'org_type', 'US firm (as in book)', 'Affiliated German firm (as in book)', 'Description']]

# %%
tenenbaum_to_csv.to_csv('../output/tenenbaum_cleaned.csv', index=False)
