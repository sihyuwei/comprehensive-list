# %%
import pandas as pd
import gspread
from gspread_dataframe import set_with_dataframe
from oauth2client.service_account import ServiceAccountCredentials

# Auth
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('../gspread_creds.json', scope)
client = gspread.authorize(creds)

# %% [markdown]
# ### TFR-500

# %%
# Open the sheet
worksheet = client.open("tfr500_summarized").worksheet("classified")

# Get all records as list of dicts
records = worksheet.get_all_records()

# Convert to DataFrame
tfr500 = pd.DataFrame(records)

# %%
tfr500_gmbh = tfr500[tfr500['Type of Organization']=='GmbH']
tfr500_gmbh = tfr500_gmbh.groupby(['Name of Foreign Business', 'American Owner - Name']).first().reset_index()

# %%
tfr500_gmbh = tfr500_gmbh.rename(columns={
    'American Owner - Name': 'Master US firm name',
    'Name of Foreign Business': 'Master German firm name'
})

tfr500_gmbh = tfr500_gmbh[['Master US firm name', 'Master German firm name']]

# %%
tfr500_gmbh[tfr500_gmbh['Master German firm name'].str.contains('West')]
# Out:
#                      Master US firm name  \
# 79         Hugo Stinnes Industries, Inc.
# 201      Socony-Vacuum Oil Company, Inc.
# 202  Western Electric Export Corporation
# 203   The Westinghouse Air Brake Company
#
#                       Master German firm name
# 79                          H. Westphal & Co.
# 201              West-Oel Gesellschaft m.b.H.
# 202                 Western Electric G.m.b.H.
# 203  Westinghouse Bremsen Gesellschaft m.b.H.

# %% [markdown]
# ### Moody's 1932

# %%
# Open the sheet
worksheet = client.open("Moodys 1932").worksheet("reviewed-expanded")

# Get all records as list of dicts
records = worksheet.get_all_records()

# Convert to DataFrame
moodys32 = pd.DataFrame(records)

# %%
moodys32_gmbh = moodys32[moodys32['subsidiary is GmbH']=='TRUE']
moodys32_gmbh = moodys32_gmbh[['Master US firm name', 'affiliated German firm name', 'Master German firm name']]

# %%
tfr500_moodys32 = tfr500_gmbh.merge(moodys32_gmbh, on='Master German firm name', how='outer', indicator=True, 
                                    suffixes=['', '_moodys32'])

tfr500_moodys32['in TFR-500'] = tfr500_moodys32['_merge'].isin(['left_only', 'both'])
tfr500_moodys32['in Moodys 32'] = tfr500_moodys32['_merge'].isin(['right_only', 'both'])

tfr500_moodys32['Master US firm name'] = tfr500_moodys32['Master US firm name'].fillna(tfr500_moodys32['Master US firm name_moodys32'])

tfr500_moodys32 = tfr500_moodys32.drop(columns=['_merge', 'Master US firm name_moodys32', 'affiliated German firm name'])

# %%
tfr500_moodys32
# Out:
#                              Master US firm name  \
# 0                        Swiss "Borvisk" Company
# 1              Standard Oil Company (New Jersey)
# 2    International Telephone and Telegraph Corp.
# 3           Edward G. Budd Manufacturing Company
# 4            The ARMCO International Corporation
# ..                                           ...
# 223                        Kupfer Bros. Co. Inc.
# 224         The Dentists' Supply Co. of New York
# 225                        National Lead Company
# 226                Gillette Safety Rasor Company
# 227               Corn Products Refining company
#
#                                Master German firm name  in TFR-500  \
# 0    "Borvisk" Kunstseiden-Vertriebsgesellschaft, m...        True
# 1    "Gluckauf" Deutsche Oel Gesellschaft Hersfeld ...        True
# 2                "Volta" Telephon & Signalbau G.m.b.H.        True
# 3                A. B. P. Gefolgschoftsheime, G.m.b.H.        True
# 4                                 ARMCO Eisen G.m.b.H.        True
# ..                                                 ...         ...
# 223                       Wilheim Stern & Co. G.m.b.H.        True
# 224                    Zahnfabrik Wienand Soehne & Co.        True
# 225                    Zinnwerke Wilheimsburg G.m.b.H.        True
# 226                            Zoellner Werke G.m.b.H.        True
# 227                              Zuckerrubensaftfabrik        True
#
#      in Moodys 32
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 223         False
# 224         False
# 225         False
# 226         False
# 227         False
#
# [228 rows x 4 columns]

# %% [markdown]
# ### Moody's 1934

# %%
# Open the sheet
worksheet = client.open("Moodys 1934").worksheet("reviewed-expanded")

# Get all records as list of dicts
records = worksheet.get_all_records()

# Convert to DataFrame
moodys34 = pd.DataFrame(records)

# %%
moodys34_gmbh = moodys34[moodys34['subsidiary is GmbH']=='TRUE']
moodys34_gmbh = moodys34_gmbh[['Master US firm name', 'affiliated German firm name', 'Master German firm name']]

moodys34_gmbh
# Out:
#                                    Master US firm name  \
# 8                                       Bakelite Corp.
# 15                       The Atlantic Refining Company
# 16                       The Atlantic Refining Company
# 22                    The Hobart Manufacturing Company
# 24                       Hugo Stinnes Industries, Inc.
# 25                       Hugo Stinnes Industries, Inc.
# 26   American Radiator & Standard Sanitary Corporation
# 27   American Radiator & Standard Sanitary Corporation
# 32                      I. B. Kleinert Rubbert Company
# 35                                      Norton Company
# 40                               Intertype Corporation
# 41                               Intertype Corporation
# 42                     International Harvester Company
# 43                  Moto Meter Gauge & Equipment Corp.
# 46                Crown Cork International Corporation
# 54                             Julius Kayser & Company
# 56                          Chicago Pneumatic Tool Co.
# 57                          Chicago Pneumatic Tool Co.
# 59         United States Hoffman Machinery Corporation
# 62                          Colgate-Palmolive-Peet Co.
# 63               L. C. Smith & Corona Typewriters Inc.
# 65                               Eastman Kodak Company
# 67                               Eastman Kodak Company
# 72                       Mergenthaler Linotype Company
# 80              The Yale & Towne Manufacturing Company
# 81                Worthington Pump and Machinery Corp.
# 87                         Royal Baking Powder Company
# 89                               Otis Elevator Company
# 90                       Silesian-American Corporation
# 97                  The National Cash Register Company
# 98                               National Lead Company
# 100                                F. W. Woolworth Co.
# 102                      Tide Water Associated Oil Co.
# 103                             The Torrington Company
# 105              General Motors Acceptance Corporation
# 117                           Paramount Pictures, Inc.
# 122  Pan American Foreign Corporation (Controlled b...
# 124  Pan American Foreign Corporation (Controlled b...
# 125  Pan American Foreign Corporation (Controlled b...
# 126                           North European Oil Corp.
# 127                           North European Oil Corp.
# 128                           North European Oil Corp.
# 129                           North European Oil Corp.
# 130                           North European Oil Corp.
# 131                           North European Oil Corp.
#
#                            affiliated German firm name  \
# 8        Gorman Bakelite Corp. (Bakelite Gesellschaft)
# 15                    Atlantic Refining Co. of Germany
# 16               Allgemeine Oel Handels Ges. (Germany)
# 22               Hobart Gesellschaft, Hamburg, Germany
# 24                            Hugo Stinnes G. m. b. H.
# 25                        Gewerkschaft Mathias Stinnes
# 26   Nationale Radiator Gesellschaft, m. b. H. (Ger...
# 27                 Deutsche Standard Werke G. m. b. H.
# 32   I. B. Kleinert Rubber Co. G. m. b. H. (formerl...
# 35   Deutsche Norton Gesellschaft m.b.H., Wesseling...
# 40                     Intertype Setzmachinen G.m.b.H.
# 41              Intertype Fabric G. m. b. H. (Germany)
# 42       International Harvester G. m. b. H. (Germany)
# 43                    Moto Meter Gesellschaft m. b. H.
# 46   Continentale Crown Cork & Seal Co., G.m.b.H., ...
# 54      Kayser Textil-Gesellschaft, m. b. H. in Saxony
# 56   Internationale Pressluft & Elektricitäts Gesel...
# 57                    Berlin-Oberschoeneweide, Germany
# 59         Hoffman Bugelmaschinen Gesellschaft, berlin
# 62                          Palmolive, Binder & Ketels
# 63   L. C. Smith & Corona Schreibmaschinen G.m.b.H....
# 65                         Kodak Gesellschaft m. b. H.
# 67                      Chemische Werke Odin (Germany)
# 72          Mergenthaler Setzmaschinen-Fabrik G.m.b.H.
# 80       Boge & Kastern, G.m.b.H. of Solingen, Germany
# 81   Deustche Worthington Gesellschaft, m.b.H., ger...
# 87   Deutsche Royal Backpulver, Gesellschaft m.b.H....
# 89                          Otis Aufzugswerke G.m.b.H.
# 90   Georg von Giesche's Heirs Mining Co. (Bergwerk...
# 97        National Register Kassen Gesellschaft M.b.H.
# 98                          Titangesellschaft M. B. H.
# 100   F. W. Woolworth Co. G. m. b. H., Berlin, Germany
# 102  Hamburg-Amerikanische Mineralol-Gesellschaft, ...
# 103  Metallwaaren Gesellschaft m.b.H., of Aachen, G...
# 105  Continental Allgemeine Finanzierungs-Gesellsch...
# 117  Paramount Film Vertrieb G.m.b.H., Berlin, Germany
# 122                  Ebano Asphalt Gesellschaft m.b.H.
# 124                        Euphalt Gesellschaft m.b.H.
# 125                    Teebaustoff Gesellschaft m.b.H.
# 126                                  West-Oel G.m.b.H.
# 127  Erdoelwerke Wathlingen, Wuerttembergische Mine...
# 128            Nordeuropaeische Oelgesellschaft m.b.H.
# 129                        Gewerkschaft Regina zu Caan
# 130     Oldenburgische Oelausbeutungesellschaft m.b.H.
# 131                         Harburger Bergbau G.m.b.H.
#
#                                Master German firm name
# 8                                Bakelite Gesellschaft
# 15          The Atlantic Refining Company Germany GmbH
# 16              Allgemeine Oel-Handels, GmbH. (Oelhag)
# 22               Hobart Maschinen Gesellschaft, m.b.H.
# 24                               Hugo Stinnes G.m.b.H.
# 25                            Mathias Stinnes G.m.b.H.
# 26              Nationale Radiator Gesellschaft m.b.H.
# 27                 Deutsche Standard Werke G. m. b. H.
# 32   Kleinerts Hanseatische, Gummiwerke Gesellschaf...
# 35                Deutsche Norton-Gesellschaft, m.b.H.
# 40                    Intertype Setzmaschinen G.m.b.H.
# 41                           Intertype Fabrik G.m.b.H.
# 42             International Harvester Company, m.b.H.
# 43                   Moto Meter Gesellschaft, m. b. H.
# 46   Continentale Crown Cork & Seal Co., G.m.b.H., ...
# 54     Kayser Textile-Gesellschaft, m. b. H. in Saxony
# 56   Internationale Pressluft und Elektricitats Ges...
# 57                    Berlin-Oberschoeneweide, Germany
# 59          Hoffman Bugelmaschinen Gesellschaft m.b.H.
# 62                  Palmolive-Binder & Ketals G.m.b.H.
# 63      L. C. Smith & Corona Schreihmaschinen G.m.b.H.
# 65                         Kodak Gesellschaft m. b. H.
# 67                      Chemische Werke Odin (Germany)
# 72         Mergenthaler Setzmaschinen-Fabrik, G.m.b.H.
# 80                   B.K.S. Handelsgesellschaft m.b.H.
# 81            Deutsche Worthington Gesellschaft m.b.H.
# 87   Deutsche Royal Backpulver, Gesellschaft m.b.H,...
# 89                          Otis Aufzugswerke G.m.b.H.
# 90      Bergwerkgesellschaft Georg von Giesche's Erben
# 97           National-Krupp Registrier-Kassen G.m.b.H.
# 98                            Titangesellschaft m.b.H.
# 100                                F. W. Woolworth Co.
# 102           Hamburg-Amerikanische Mineralol-G.m.b.H.
# 103      Metallwaaren Gesellschaft m. b. H., of Aachen
# 105       Allgemeine Finanzierungs Gesellschaft m.b.H.
# 117  Paramount Film Vertreib G. m. b. H., Berlin, G...
# 122                  Ebano Asphalt Gesellschaft m.b.H.
# 124                        Euphalt Gesellschaft m.b.H.
# 125                   Teerbaustoff Gesellschaft m.b.H.
# 126                       West-Oel Gesellschaft m.b.H.
# 127  Erdoelwerke Wathlingen, Wuerttembergische Mine...
# 128            Nordeuropaeische Oelgesellschaft m.b.H.
# 129                        Gewerkschaft Regina zu Caan
# 130     Oldenburgische Oelausbeutungesellschaft m.b.H.
# 131                         Harburger Bergbau G.m.b.H.

# %%
tfr500_moodys32_moodys34 = tfr500_moodys32.merge(moodys34_gmbh, on='Master German firm name', how='outer', indicator=True,
                                                 suffixes=['', '_moodys34'])

tfr500_moodys32_moodys34['in TFR-500'] = tfr500_moodys32_moodys34['in TFR-500'].fillna(False)
tfr500_moodys32_moodys34['in Moodys 32'] = tfr500_moodys32_moodys34['in Moodys 32'].fillna(False)
tfr500_moodys32_moodys34['in Moodys 34'] = tfr500_moodys32_moodys34['_merge'].isin(['right_only', 'both'])

tfr500_moodys32_moodys34['Master US firm name'] = tfr500_moodys32_moodys34['Master US firm name'].fillna(tfr500_moodys32_moodys34['Master US firm name_moodys34'])

tfr500_moodys32_moodys34 = tfr500_moodys32_moodys34.drop(columns=['_merge', 'Master US firm name_moodys34', 'affiliated German firm name'])
# Out:
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_34248/3087841367.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34['in TFR-500'] = tfr500_moodys32_moodys34['in TFR-500'].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_34248/3087841367.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34['in Moodys 32'] = tfr500_moodys32_moodys34['in Moodys 32'].fillna(False)

# %%
tfr500_moodys32_moodys34
# Out:
#                              Master US firm name  \
# 0                        Swiss "Borvisk" Company
# 1              Standard Oil Company (New Jersey)
# 2    International Telephone and Telegraph Corp.
# 3           Edward G. Budd Manufacturing Company
# 4            The ARMCO International Corporation
# ..                                           ...
# 236                        Kupfer Bros. Co. Inc.
# 237         The Dentists' Supply Co. of New York
# 238                        National Lead Company
# 239                Gillette Safety Rasor Company
# 240               Corn Products Refining company
#
#                                Master German firm name  in TFR-500  \
# 0    "Borvisk" Kunstseiden-Vertriebsgesellschaft, m...        True
# 1    "Gluckauf" Deutsche Oel Gesellschaft Hersfeld ...        True
# 2                "Volta" Telephon & Signalbau G.m.b.H.        True
# 3                A. B. P. Gefolgschoftsheime, G.m.b.H.        True
# 4                                 ARMCO Eisen G.m.b.H.        True
# ..                                                 ...         ...
# 236                       Wilheim Stern & Co. G.m.b.H.        True
# 237                    Zahnfabrik Wienand Soehne & Co.        True
# 238                    Zinnwerke Wilheimsburg G.m.b.H.        True
# 239                            Zoellner Werke G.m.b.H.        True
# 240                              Zuckerrubensaftfabrik        True
#
#      in Moodys 32  in Moodys 34
# 0           False         False
# 1           False         False
# 2           False         False
# 3           False         False
# 4           False         False
# ..            ...           ...
# 236         False         False
# 237         False         False
# 238         False         False
# 239         False         False
# 240         False         False
#
# [241 rows x 5 columns]

# %% [markdown]
# ### Tenenbaum

# %%
# Open the sheet
worksheet = client.open("Tenenbaum").worksheet("Sheet1 expanded")

# Get all records as list of dicts
records = worksheet.get_all_records()

# Convert to DataFrame
tenenbaum = pd.DataFrame(records)

# %%
tenenbaum_gmbh = tenenbaum[tenenbaum['subsidiary is GmbH']=='TRUE']
tenenbaum_gmbh = tenenbaum_gmbh[['Master US firm name', 'affiliated German firm name', 'Master German firm name']]

# %%
tfr500_moodys32_moodys34_tenenbaum = tfr500_moodys32_moodys34.merge(tenenbaum_gmbh, on='Master German firm name', how='outer', indicator=True,
                                                 suffixes=['', '_Tenenbaum'])

tfr500_moodys32_moodys34_tenenbaum['in TFR-500'] = tfr500_moodys32_moodys34_tenenbaum['in TFR-500'].fillna(False)
tfr500_moodys32_moodys34_tenenbaum['in Moodys 32'] = tfr500_moodys32_moodys34_tenenbaum['in Moodys 32'].fillna(False)
tfr500_moodys32_moodys34_tenenbaum['in Moodys 34'] = tfr500_moodys32_moodys34_tenenbaum['in Moodys 34'].fillna(False)
tfr500_moodys32_moodys34_tenenbaum['in Tenenbaum'] = tfr500_moodys32_moodys34_tenenbaum['_merge'].isin(['right_only', 'both'])

tfr500_moodys32_moodys34_tenenbaum['Master US firm name'] = tfr500_moodys32_moodys34_tenenbaum['Master US firm name'].fillna(tfr500_moodys32_moodys34_tenenbaum['Master US firm name_Tenenbaum'])

tfr500_moodys32_moodys34_tenenbaum = tfr500_moodys32_moodys34_tenenbaum.drop(columns=['_merge', 'Master US firm name_Tenenbaum', 'affiliated German firm name'])
# Out:
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_34248/855677672.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34_tenenbaum['in TFR-500'] = tfr500_moodys32_moodys34_tenenbaum['in TFR-500'].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_34248/855677672.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34_tenenbaum['in Moodys 32'] = tfr500_moodys32_moodys34_tenenbaum['in Moodys 32'].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_34248/855677672.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34_tenenbaum['in Moodys 34'] = tfr500_moodys32_moodys34_tenenbaum['in Moodys 34'].fillna(False)

# %%
tfr500_moodys32_moodys34_tenenbaum
# Out:
#                              Master US firm name  \
# 0                        Swiss "Borvisk" Company
# 1              Standard Oil Company (New Jersey)
# 2    International Telephone and Telegraph Corp.
# 3           Edward G. Budd Manufacturing Company
# 4            The ARMCO International Corporation
# ..                                           ...
# 245                        Kupfer Bros. Co. Inc.
# 246         The Dentists' Supply Co. of New York
# 247                        National Lead Company
# 248                Gillette Safety Rasor Company
# 249               Corn Products Refining company
#
#                                Master German firm name  in TFR-500  \
# 0    "Borvisk" Kunstseiden-Vertriebsgesellschaft, m...        True
# 1    "Gluckauf" Deutsche Oel Gesellschaft Hersfeld ...        True
# 2                "Volta" Telephon & Signalbau G.m.b.H.        True
# 3                A. B. P. Gefolgschoftsheime, G.m.b.H.        True
# 4                                 ARMCO Eisen G.m.b.H.        True
# ..                                                 ...         ...
# 245                       Wilheim Stern & Co. G.m.b.H.        True
# 246                    Zahnfabrik Wienand Soehne & Co.        True
# 247                    Zinnwerke Wilheimsburg G.m.b.H.        True
# 248                            Zoellner Werke G.m.b.H.        True
# 249                              Zuckerrubensaftfabrik        True
#
#      in Moodys 32  in Moodys 34  in Tenenbaum
# 0           False         False         False
# 1           False         False         False
# 2           False         False          True
# 3           False         False         False
# 4           False         False          True
# ..            ...           ...           ...
# 245         False         False         False
# 246         False         False         False
# 247         False         False         False
# 248         False         False         False
# 249         False         False         False
#
# [250 rows x 6 columns]

# %%
tfr500_moodys32_moodys34_tenenbaum.to_csv('output/gmbh_tfr500_moodys32_moodys34_tenenbaum.csv')

# %%
tfr500_moodys32_moodys34_tenenbaum[(tfr500_moodys32_moodys34_tenenbaum['in TFR-500']==True) &
                                   (tfr500_moodys32_moodys34_tenenbaum['in Moodys 32']==False) & 
                                   (tfr500_moodys32_moodys34_tenenbaum['in Moodys 34']==False) & 
                                   (tfr500_moodys32_moodys34_tenenbaum['in Tenenbaum']==False)]
# Out:
#                       Master US firm name  \
# 0                 Swiss "Borvisk" Company
# 1       Standard Oil Company (New Jersey)
# 3    Edward G. Budd Manufacturing Company
# 6        Underwood Elliott Fisher Company
# 7                       Jadev Corporation
# ..                                    ...
# 245                 Kupfer Bros. Co. Inc.
# 246  The Dentists' Supply Co. of New York
# 247                 National Lead Company
# 248         Gillette Safety Rasor Company
# 249        Corn Products Refining company
#
#                                Master German firm name  in TFR-500  \
# 0    "Borvisk" Kunstseiden-Vertriebsgesellschaft, m...        True
# 1    "Gluckauf" Deutsche Oel Gesellschaft Hersfeld ...        True
# 3                A. B. P. Gefolgschoftsheime, G.m.b.H.        True
# 6                        Adrema Maschinenebau G.m.b.H.        True
# 7                Allgemeine Erdol Gesellschaft, m.b.H.        True
# ..                                                 ...         ...
# 245                       Wilheim Stern & Co. G.m.b.H.        True
# 246                    Zahnfabrik Wienand Soehne & Co.        True
# 247                    Zinnwerke Wilheimsburg G.m.b.H.        True
# 248                            Zoellner Werke G.m.b.H.        True
# 249                              Zuckerrubensaftfabrik        True
#
#      in Moodys 32  in Moodys 34  in Tenenbaum
# 0           False         False         False
# 1           False         False         False
# 3           False         False         False
# 6           False         False         False
# 7           False         False         False
# ..            ...           ...           ...
# 245         False         False         False
# 246         False         False         False
# 247         False         False         False
# 248         False         False         False
# 249         False         False         False
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Handbuch GmbH

# %%
hb_gmbh = pd.read_excel('../../Moodys_name_to_handbuch/output/manual/gmbh_validated.xlsx', sheet_name='validated')
hb_gmbh = hb_gmbh[hb_gmbh['validated'].isin(['USC', 'USO', 'USOP'])]

hb_gmbh["is_duplicate"] = hb_gmbh.duplicated(subset=['Master German firm name', 'Master US firm name'])
# dropping duplicates
hb_gmbh = hb_gmbh[hb_gmbh["is_duplicate"] == False]

hb_gmbh = hb_gmbh[['german_name', 'Master German firm name', 'US_name', 'Master US firm name', 'validated']]

# %%
hb_gmbh_full = pd.read_csv('../../Handbuch_GmbH_1932/output/firms_structured.csv')

# %%
# merging back to HB GmbH

# for those matched to more than on GmbH in the Handbuch (Handbuch has a few firms with identical names), we keep only the first match
hb_gmbh_to_match = hb_gmbh_full[hb_gmbh_full['firm_name'].notnull()]
hb_gmbh_to_match = hb_gmbh_to_match.groupby('firm_name').first()

# merging back to the HB GmbH to access the rest of the information on the GmbH
hb_gmbh_merged_back = hb_gmbh.rename(columns={'german_name': 'firm_name'}).merge(hb_gmbh_to_match, on='firm_name', how='left')

# %%
hb_gmbh_counts = hb_gmbh['validated'].value_counts().reset_index()
hb_gmbh_counts.to_latex('output/table/HB_GmbH_count.tex', index=False)

# %%
hb_gmbh= hb_gmbh.rename(columns={'validated': 'HB GmbH class'})

# %%
tfr500_moodys32_moodys34_tenenbaum_hb_gmbh = tfr500_moodys32_moodys34_tenenbaum.merge(hb_gmbh, on=['Master German firm name', 'Master US firm name'], how='outer', indicator=True,
                                                 suffixes=['', '_hb_gmbh'], validate='one_to_one')

tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['in TFR-500'] = tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['in TFR-500'].fillna(False)
tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['in Moodys 32'] = tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['in Moodys 32'].fillna(False)
tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['in Moodys 34'] = tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['in Moodys 34'].fillna(False)
tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['in Tenenbaum'] = tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['in Tenenbaum'].fillna(False)
tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['IDed in HB GmbH'] = tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['_merge'].isin(['right_only', 'both'])

tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['Master US firm name'] = tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['Master US firm name'].fillna(tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['US_name'])

tfr500_moodys32_moodys34_tenenbaum_hb_gmbh = tfr500_moodys32_moodys34_tenenbaum_hb_gmbh.drop(columns=['_merge', 'german_name', 'US_name'])
tfr500_moodys32_moodys34_tenenbaum_hb_gmbh
# Out:
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_34248/1793962513.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['in TFR-500'] = tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['in TFR-500'].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_34248/1793962513.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['in Moodys 32'] = tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['in Moodys 32'].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_34248/1793962513.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['in Moodys 34'] = tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['in Moodys 34'].fillna(False)
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_34248/1793962513.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['in Tenenbaum'] = tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['in Tenenbaum'].fillna(False)
#                              Master US firm name  \
# 0                        Swiss "Borvisk" Company
# 1              Standard Oil Company (New Jersey)
# 2    International Telephone and Telegraph Corp.
# 3           Edward G. Budd Manufacturing Company
# 4            The ARMCO International Corporation
# ..                                           ...
# 265                        Kupfer Bros. Co. Inc.
# 266         The Dentists' Supply Co. of New York
# 267                        National Lead Company
# 268                Gillette Safety Rasor Company
# 269               Corn Products Refining company
#
#                                Master German firm name  in TFR-500  \
# 0    "Borvisk" Kunstseiden-Vertriebsgesellschaft, m...        True
# 1    "Gluckauf" Deutsche Oel Gesellschaft Hersfeld ...        True
# 2                "Volta" Telephon & Signalbau G.m.b.H.        True
# 3                A. B. P. Gefolgschoftsheime, G.m.b.H.        True
# 4                                 ARMCO Eisen G.m.b.H.        True
# ..                                                 ...         ...
# 265                       Wilheim Stern & Co. G.m.b.H.        True
# 266                    Zahnfabrik Wienand Soehne & Co.        True
# 267                    Zinnwerke Wilheimsburg G.m.b.H.        True
# 268                            Zoellner Werke G.m.b.H.        True
# 269                              Zuckerrubensaftfabrik        True
#
#      in Moodys 32  in Moodys 34  in Tenenbaum HB GmbH class  IDed in HB GmbH
# 0           False         False         False           NaN            False
# 1           False         False         False           NaN            False
# 2           False         False          True           NaN            False
# 3           False         False         False           NaN            False
# 4           False         False          True           NaN            False
# ..            ...           ...           ...           ...              ...
# 265         False         False         False           NaN            False
# 266         False         False         False           NaN            False
# 267         False         False         False           NaN            False
# 268         False         False         False           NaN            False
# 269         False         False         False           NaN            False
#
# [270 rows x 8 columns]

# %%
tfr500_moodys32_moodys34_tenenbaum_hb_gmbh.to_csv('output/gmbh_tfr500_moodys32_moodys34_tenenbaum_hb_gmbh.csv')

# %% [markdown]
# ### Search for all firms in the HB GmbH 1932

# %%
not_ided_in_HB = tfr500_moodys32_moodys34_tenenbaum_hb_gmbh[tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['IDed in HB GmbH']==False]

# %%
hb_gmbh_full = pd.read_csv('../../Handbuch_GmbH_1932/output/firms_structured.csv')

# %% [markdown]
# #### fuzzy matching

# %%
from rapidfuzz import process, fuzz

# Function to get top 3 matches from df_b for each row in df_a
def get_best_match(query, choices, scorer=fuzz.token_sort_ratio):
    """Return the single best fuzzy match."""
    match, score, idx = process.extractOne(query, choices, scorer=scorer)
    return match, score, idx

results = []

# Loop through df_a
for i, row in not_ided_in_HB.iterrows():
    query = row["Master German firm name"]
    match, score, idx = get_best_match(query, hb_gmbh_full["firm_name"].tolist())
    
    # merge row from A with its best match from B
    match_row = hb_gmbh_full.iloc[idx].to_dict()
    combined = {**row.to_dict(), **match_row}
    combined["fuzzy_score"] = score
    results.append(combined)

# Final result with all columns from A + B + score
matches_df = pd.DataFrame(results)

# %%
# loads the previous manual checking results
matches_df_checked = pd.read_excel('manual/hb_gmbh_32_fuzzy_matched_checked.xlsx')
matches_df_checked = matches_df_checked[['Master German firm name', 'firm_name', 'match_is_good']].groupby(['Master German firm name', 'firm_name', 'match_is_good']).first().reset_index()
matches_df_auto_manual_merged = matches_df.merge(matches_df_checked[['Master German firm name', 'firm_name', 'match_is_good']], 
                 on=['Master German firm name', 'firm_name'],
                 how='left')
matches_df_auto_manual_merged
# Out:
#                              Master US firm name  \
# 0                        Swiss "Borvisk" Company
# 1              Standard Oil Company (New Jersey)
# 2    International Telephone and Telegraph Corp.
# 3           Edward G. Budd Manufacturing Company
# 4            The ARMCO International Corporation
# ..                                           ...
# 230                        Kupfer Bros. Co. Inc.
# 231         The Dentists' Supply Co. of New York
# 232                        National Lead Company
# 233                Gillette Safety Rasor Company
# 234               Corn Products Refining company
#
#                                Master German firm name  in TFR-500  \
# 0    "Borvisk" Kunstseiden-Vertriebsgesellschaft, m...        True
# 1    "Gluckauf" Deutsche Oel Gesellschaft Hersfeld ...        True
# 2                "Volta" Telephon & Signalbau G.m.b.H.        True
# 3                A. B. P. Gefolgschoftsheime, G.m.b.H.        True
# 4                                 ARMCO Eisen G.m.b.H.        True
# ..                                                 ...         ...
# 230                       Wilheim Stern & Co. G.m.b.H.        True
# 231                    Zahnfabrik Wienand Soehne & Co.        True
# 232                    Zinnwerke Wilheimsburg G.m.b.H.        True
# 233                            Zoellner Werke G.m.b.H.        True
# 234                              Zuckerrubensaftfabrik        True
#
#      in Moodys 32  in Moodys 34  in Tenenbaum  HB GmbH class  IDed in HB GmbH  \
# 0           False         False         False            NaN            False
# 1           False         False         False            NaN            False
# 2           False         False          True            NaN            False
# 3           False         False         False            NaN            False
# 4           False         False          True            NaN            False
# ..            ...           ...           ...            ...              ...
# 230         False         False         False            NaN            False
# 231         False         False         False            NaN            False
# 232         False         False         False            NaN            False
# 233         False         False         False            NaN            False
# 234         False         False         False            NaN            False
#
#      index  page column                                        firm_name  \
# 0      299   166  right        Borvisk-Kunstseiden Vertriebsgesellschaft
# 1      521   277  right  Deutsche Racine Gesellschaft Rudolf Bauer & Co.
# 2     2573  1303  right                    Volta Telephon- und Signalbau
# 3      901   467  right                             R.K. Ad. Gochsheimer
# 4      414   224   left                                  A. F. H. Eilers
# ..     ...   ...    ...                                              ...
# 230   2320  1177   left                              Wilhelm Stern & Co.
# 231   2733  1383  right                   Zahnfabrik Wienand Söhne & Co.
# 232   2760  1397   left                           Zinnwerke Wilhelmsburg
# 233   2626  1330   left                                       Im. Weller
# 234   2769  1401  right                                  Zuckerrübensaft
#
#                                               location        date  \
# 0                           Berlin W 62, Maaßenstr. 36     26.5.15
# 1                           Berlin NW 6, Luisenstr. 21      6.7.27
# 2                     Berlin W 35, Potsdamei-Straße 38      1.7.05
# 3                    Frankfurt a. M., Kaiserhofstr. 12     28.1.16
# 4                           Hamburg, Farmsener Str. 28  29. 12. 19
# ..                                                 ...         ...
# 230                                              Fürth      2.9.11
# 231                             Sprendlingen in Hessen      7.6.21
# 232                           Wilhelmsburg bei Harburg    12.11.03
# 233                                             Berlin   7. 11. 20
# 234  Berlin-Charlottenburg, Joachimsthaler Straße 4...    15.10.23
#
#           capital                                           business  \
# 0       RM 40 000                         Herstellung von Kunstseide
# 1        RM 20000  Vertrieb der elektrischen „Racine“ Parkettbode...
# 2      RM 268 000  Installation, Verkauf von Telefon-, Telegrafen...
# 3        RM 16000  Handel mit Weinen, Spirituosen und sonstigen e...
# 4         RM 1000                          Kohlen- und Koks-Geschäft
# ..            ...                                                ...
# 230    RM 500,000  Herstellung von Metall-, Bunt- und Luxuspapier...
# 231    RM 800 000                 Fabrikation von künstlichen Zähnen
# 232  RM 1 500 000  Umwandlung von Erzen, Rohmetallen u. Hüttenpro...
# 233     RM 50 000                                       Tuchhandlung
# 234        RM 500  Verwertung des von den Gesellschaftern hergest...
#
#                                           persons  \
# 0              Dr. jur. E. Wohrizek; Alfr. Demant
# 1                              R. Bauer; F. Bauer
# 2                        A. Hoffmann; L. Hoepfner
# 3                                Jak. Gochsheimer
# 4                                 Richard Mildner
# ..                                            ...
# 230  B. Kaufmann; stellv. Dir. Erhard Ottenberger
# 231                Dr. Aug. und Dr. Fritz Wienand
# 232            Henryk Goldmann; Dr. phil. W. Baer
# 233                          Siegfr. Lichtenstein
# 234                                     Hans Pape
#
#                                                   type  fuzzy_score  \
# 0                   2 Gf. od. 1 Gf. u. 1 Pk. od. 2 Pk.    84.782609
# 1                                             Jed. Gf.    59.259259
# 2                                          2 Gf. gern.    54.545455
# 3                                              Der Gf.    52.631579
# 4                                             Jed. Gf.    51.428571
# ..                                                 ...          ...
# 230  vertr. jeder allein, sonst 2 Gf. od. 1 Gf. u. ...    76.595745
# 231                                           Jed. Gf.    95.081967
# 232                 2 Gf. od. 1 Gf. u. 1 Pk. od. 2 Pk.    79.245283
# 233                                        1 od. 2 Gf.    54.545455
# 234                                            Der Gf.    77.777778
#
#      match_is_good
# 0              1.0
# 1              0.0
# 2              1.0
# 3              0.0
# 4              0.0
# ..             ...
# 230            1.0
# 231            1.0
# 232            1.0
# 233            0.0
# 234            1.0
#
# [235 rows x 20 columns]

# %%
matches_df_auto_manual_merged.to_excel('output/hb_gmbh_32_fuzzy_matched_auto.xlsx', index=False)

# %%
# after the manual updates on matches_df_auto_manual_merged
matches_df_checked = pd.read_excel('manual/hb_gmbh_32_fuzzy_matched_checked.xlsx')

# %%
matches_df_checked
# Out:
#                              Master US firm name  \
# 0                        Swiss "Borvisk" Company
# 1              Standard Oil Company (New Jersey)
# 2    International Telephone and Telegraph Corp.
# 3           Edward G. Budd Manufacturing Company
# 4            The ARMCO International Corporation
# ..                                           ...
# 230                        Kupfer Bros. Co. Inc.
# 231         The Dentists' Supply Co. of New York
# 232                        National Lead Company
# 233                Gillette Safety Rasor Company
# 234               Corn Products Refining company
#
#                                Master German firm name  in TFR-500  \
# 0    "Borvisk" Kunstseiden-Vertriebsgesellschaft, m...        True
# 1    "Gluckauf" Deutsche Oel Gesellschaft Hersfeld ...        True
# 2                "Volta" Telephon & Signalbau G.m.b.H.        True
# 3                A. B. P. Gefolgschoftsheime, G.m.b.H.        True
# 4                                 ARMCO Eisen G.m.b.H.        True
# ..                                                 ...         ...
# 230                       Wilheim Stern & Co. G.m.b.H.        True
# 231                    Zahnfabrik Wienand Soehne & Co.        True
# 232                    Zinnwerke Wilheimsburg G.m.b.H.        True
# 233                            Zoellner Werke G.m.b.H.        True
# 234                              Zuckerrubensaftfabrik        True
#
#      in Moodys 32  in Moodys 34  in Tenenbaum  HB GmbH class  IDed in HB GmbH  \
# 0           False         False         False            NaN            False
# 1           False         False         False            NaN            False
# 2           False         False          True            NaN            False
# 3           False         False         False            NaN            False
# 4           False         False          True            NaN            False
# ..            ...           ...           ...            ...              ...
# 230         False         False         False            NaN            False
# 231         False         False         False            NaN            False
# 232         False         False         False            NaN            False
# 233         False         False         False            NaN            False
# 234         False         False         False            NaN            False
#
#      index  page column                                        firm_name  \
# 0      299   166  right        Borvisk-Kunstseiden Vertriebsgesellschaft
# 1      521   277  right  Deutsche Racine Gesellschaft Rudolf Bauer & Co.
# 2     2573  1303  right                    Volta Telephon- und Signalbau
# 3      901   467  right                             R.K. Ad. Gochsheimer
# 4      414   224   left                                  A. F. H. Eilers
# ..     ...   ...    ...                                              ...
# 230   2320  1177   left                              Wilhelm Stern & Co.
# 231   2733  1383  right                   Zahnfabrik Wienand Söhne & Co.
# 232   2760  1397   left                           Zinnwerke Wilhelmsburg
# 233   2626  1330   left                                       Im. Weller
# 234   2769  1401  right                                  Zuckerrübensaft
#
#                                               location        date  \
# 0                           Berlin W 62, Maaßenstr. 36     26.5.15
# 1                           Berlin NW 6, Luisenstr. 21      6.7.27
# 2                     Berlin W 35, Potsdamei-Straße 38      1.7.05
# 3                    Frankfurt a. M., Kaiserhofstr. 12     28.1.16
# 4                           Hamburg, Farmsener Str. 28  29. 12. 19
# ..                                                 ...         ...
# 230                                              Fürth      2.9.11
# 231                             Sprendlingen in Hessen      7.6.21
# 232                           Wilhelmsburg bei Harburg    12.11.03
# 233                                             Berlin   7. 11. 20
# 234  Berlin-Charlottenburg, Joachimsthaler Straße 4...    15.10.23
#
#           capital                                           business  \
# 0       RM 40 000                         Herstellung von Kunstseide
# 1        RM 20000  Vertrieb der elektrischen „Racine“ Parkettbode...
# 2      RM 268 000  Installation, Verkauf von Telefon-, Telegrafen...
# 3        RM 16000  Handel mit Weinen, Spirituosen und sonstigen e...
# 4         RM 1000                          Kohlen- und Koks-Geschäft
# ..            ...                                                ...
# 230    RM 500,000  Herstellung von Metall-, Bunt- und Luxuspapier...
# 231    RM 800 000                 Fabrikation von künstlichen Zähnen
# 232  RM 1 500 000  Umwandlung von Erzen, Rohmetallen u. Hüttenpro...
# 233     RM 50 000                                       Tuchhandlung
# 234        RM 500  Verwertung des von den Gesellschaftern hergest...
#
#                                           persons  \
# 0              Dr. jur. E. Wohrizek; Alfr. Demant
# 1                              R. Bauer; F. Bauer
# 2                        A. Hoffmann; L. Hoepfner
# 3                                Jak. Gochsheimer
# 4                                 Richard Mildner
# ..                                            ...
# 230  B. Kaufmann; stellv. Dir. Erhard Ottenberger
# 231                Dr. Aug. und Dr. Fritz Wienand
# 232            Henryk Goldmann; Dr. phil. W. Baer
# 233                          Siegfr. Lichtenstein
# 234                                     Hans Pape
#
#                                                   type  fuzzy_score  \
# 0                   2 Gf. od. 1 Gf. u. 1 Pk. od. 2 Pk.    84.782609
# 1                                             Jed. Gf.    59.259259
# 2                                          2 Gf. gern.    54.545455
# 3                                              Der Gf.    52.631579
# 4                                             Jed. Gf.    51.428571
# ..                                                 ...          ...
# 230  vertr. jeder allein, sonst 2 Gf. od. 1 Gf. u. ...    76.595745
# 231                                           Jed. Gf.    95.081967
# 232                 2 Gf. od. 1 Gf. u. 1 Pk. od. 2 Pk.    79.245283
# 233                                        1 od. 2 Gf.    54.545455
# 234                                            Der Gf.    77.777778
#
#      match_is_good
# 0                1
# 1                0
# 2                1
# 3                0
# 4                0
# ..             ...
# 230              1
# 231              1
# 232              1
# 233              0
# 234              1
#
# [235 rows x 20 columns]

# %% [markdown]
# #### manually checking the rest

# %%
needs_manual_search = matches_df_checked[matches_df_checked['match_is_good']==0]
needs_manual_search = needs_manual_search[['Master US firm name', 'Master German firm name', 'in TFR-500', 'in Moodys 32', 'in Moodys 34', 'in Tenenbaum', 'IDed in HB GmbH']]

# %%
manual_searched = pd.read_excel('manual/hb_gmbh_32_search_manual.xlsx')
manual_searched = manual_searched[['Master German firm name', 'firm_name', 'searched']].groupby('Master German firm name').first().reset_index()
needs_manual_search_auto_manual_merged = needs_manual_search.merge(manual_searched, 
                                                                   on='Master German firm name', 
                                                                   how='left')

# %%
needs_manual_search_auto_manual_merged.to_excel('output/hb_gmbh_32_to_search_auto.xlsx', index=False)

# %%
# after the manual updates on matches_df_auto_manual_merged
searched = pd.read_excel('manual/hb_gmbh_32_search_manual.xlsx')

# %%
# for those matched to more than on GmbH in the Handbuch (Handbuch has a few firms with identical names), we keep only the first match
hb_gmbh_to_match = hb_gmbh_full[hb_gmbh_full['firm_name'].notnull()]
hb_gmbh_to_match = hb_gmbh_to_match.groupby('firm_name').first()

# merging back to the HB GmbH to access the rest of the information on the GmbH
searched_merged_hb_gmbh = searched.merge(hb_gmbh_to_match, on='firm_name', how='left')


# concating the firms fuzzy matched and manually searched
fuzzy_searched_merged_hb_gmbh = pd.concat([searched_merged_hb_gmbh, matches_df_checked[matches_df_checked['match_is_good']==1]]).reset_index()
fuzzy_searched_merged_hb_gmbh
# Out:
#      level_0                   Master US firm name  \
# 0          0     Standard Oil Company (New Jersey)
# 1          1  Edward G. Budd Manufacturing Company
# 2          2   The ARMCO International Corporation
# 3          3      Underwood Elliott Fisher Company
# 4          4         The Atlantic Refining Company
# ..       ...                                   ...
# 230      228   Western Electric Export Corporation
# 231      230                 Kupfer Bros. Co. Inc.
# 232      231  The Dentists' Supply Co. of New York
# 233      232                 National Lead Company
# 234      234        Corn Products Refining company
#
#                                Master German firm name  in TFR-500  \
# 0    "Gluckauf" Deutsche Oel Gesellschaft Hersfeld ...        True
# 1                A. B. P. Gefolgschoftsheime, G.m.b.H.        True
# 2                                 ARMCO Eisen G.m.b.H.        True
# 3                        Adrema Maschinenebau G.m.b.H.        True
# 4               Allgemeine Oel-Handels, GmbH. (Oelhag)        True
# ..                                                 ...         ...
# 230                          Western Electric G.m.b.H.        True
# 231                       Wilheim Stern & Co. G.m.b.H.        True
# 232                    Zahnfabrik Wienand Soehne & Co.        True
# 233                    Zinnwerke Wilheimsburg G.m.b.H.        True
# 234                              Zuckerrubensaftfabrik        True
#
#      in Moodys 32  in Moodys 34  in Tenenbaum  IDed in HB GmbH  \
# 0           False         False         False            False
# 1           False         False         False            False
# 2           False         False          True            False
# 3           False         False         False            False
# 4           False          True          True            False
# ..            ...           ...           ...              ...
# 230         False         False         False            False
# 231         False         False         False            False
# 232         False         False         False            False
# 233         False         False         False            False
# 234         False         False         False            False
#
#                                firm_name  searched  ...  column  \
# 0                                    NaN       1.0  ...     NaN
# 1                                    NaN       1.0  ...     NaN
# 2                                    NaN       1.0  ...     NaN
# 3     „Adrema“ Maschinenbau-Gesellschaft       1.0  ...    left
# 4    Allgemeine Oel-Handels-Gesellschaft       1.0  ...    left
# ..                                   ...       ...  ...     ...
# 230            Deutsche Western Electric       NaN  ...    left
# 231                  Wilhelm Stern & Co.       NaN  ...    left
# 232       Zahnfabrik Wienand Söhne & Co.       NaN  ...   right
# 233               Zinnwerke Wilhelmsburg       NaN  ...    left
# 234                      Zuckerrübensaft       NaN  ...   right
#
#                                               location       date  \
# 0                                                  NaN        NaN
# 1                                                  NaN        NaN
# 2                                                  NaN        NaN
# 3              Berlin-Charlottenburg, Alt-Moabit 62/63   2. 4. 13
# 4                                Hamburg, Mittelweg 38  8. 12. 20
# ..                                                 ...        ...
# 230                 Berlin W 15, Emser Straße Nr 40-41  20. 6. 29
# 231                                              Fürth     2.9.11
# 232                             Sprendlingen in Hessen     7.6.21
# 233                           Wilhelmsburg bei Harburg   12.11.03
# 234  Berlin-Charlottenburg, Joachimsthaler Straße 4...   15.10.23
#
#           capital                                           business  \
# 0             NaN                                                NaN
# 1             NaN                                                NaN
# 2             NaN                                                NaN
# 3     RM 1000 000                               Maschinenfabrikation
# 4    RM 9 000 000              Handel mit Gelen und verwandten Waren
# ..            ...                                                ...
# 230    RM 200 000  Manufacture, sale, and distribution of film an...
# 231    RM 500,000  Herstellung von Metall-, Bunt- und Luxuspapier...
# 232    RM 800 000                 Fabrikation von künstlichen Zähnen
# 233  RM 1 500 000  Umwandlung von Erzen, Rohmetallen u. Hüttenpro...
# 234        RM 500  Verwertung des von den Gesellschaftern hergest...
#
#                                           persons  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                              Julius Goldschmidt
# 4                                    Emanuel Rein
# ..                                            ...
# 230                                           NaN
# 231  B. Kaufmann; stellv. Dir. Erhard Ottenberger
# 232                Dr. Aug. und Dr. Fritz Wienand
# 233            Henryk Goldmann; Dr. phil. W. Baer
# 234                                     Hans Pape
#
#                                                   type HB GmbH class  \
# 0                                                  NaN           NaN
# 1                                                  NaN           NaN
# 2                                                  NaN           NaN
# 3                                       1 Gf. od. 2 Pk           NaN
# 4                            2 Gf. od. 1 Gf. od. 2 Pk.           NaN
# ..                                                 ...           ...
# 230                                                NaN           NaN
# 231  vertr. jeder allein, sonst 2 Gf. od. 1 Gf. u. ...           NaN
# 232                                           Jed. Gf.           NaN
# 233                 2 Gf. od. 1 Gf. u. 1 Pk. od. 2 Pk.           NaN
# 234                                            Der Gf.           NaN
#
#     fuzzy_score  match_is_good
# 0           NaN            NaN
# 1           NaN            NaN
# 2           NaN            NaN
# 3           NaN            NaN
# 4           NaN            NaN
# ..          ...            ...
# 230   64.000000            1.0
# 231   76.595745            1.0
# 232   95.081967            1.0
# 233   79.245283            1.0
# 234   77.777778            1.0
#
# [235 rows x 22 columns]

# %%
hb_gmbh_merged_back_and_dummies = hb_gmbh_merged_back.merge(tfr500_moodys32_moodys34_tenenbaum_hb_gmbh.drop(columns=['HB GmbH class']), 
                                                            on=['Master US firm name', 'Master German firm name'], 
                                                            how='left', 
                                                            indicator=True)
hb_gmbh_merged_back_and_dummies
# Out:
#                             firm_name  \
# 0               American News Company
# 1                       Columbia Film
# 2                             O-Cedar
# 3                           Fairbanks
# 4           Gillette Safety Razor Co.
# 5                       Addressograph
# 6                     Aeolian Company
# 7                American Oil Company
# 8                            Bakelite
# 9           Bausch & Lomb Optical Co.
# 10                          Blaw-Knox
# 11            Boston Blacking Company
# 12                    Butler Brothers
# 13  Chesebrough Manufacturing Company
# 14                          Coca-Cola
# 15                  Corn Products Co.
# 16          Deutsche Celotex Vertrieb
# 17   Deutsche Underwood Elliot Fisher
# 18                      Durant Motors
# 19      Eagle Oil Company of New York
# 20                         Elektrolux
# 21                     General Motors
# 22                   Hobart Maschinen
# 23                     Ingersoll-Rand
# 24    International Harvester Company
# 25               Kraft Cheese Company
# 26                         Parker Pen
# 27    Philip Morris & Company Limited
# 28                Quaker Oats Company
# 29                Reece Machinery Co.
# 30               S. Oppenheimer & Co.
# 31    German American Tobacco Company
# 32             Holophane-Gesellschaft
# 33                        Hupp Motors
# 34                W. T. Grant Company
#
#                        Master German firm name  \
# 0                        American News Company
# 1                                Columbia Film
# 2                                      O-Cedar
# 3               The Fairbanks G.m.b.H. Company
# 4                    Gillette Safety Razor Co.
# 5            Addressograph-Multigraph G.m.b.H.
# 6                              Aeolian Company
# 7                         American Oil Company
# 8                        Bakelite Gesellschaft
# 9                    Bausch & Lomb Optical Co.
# 10                                   Blaw-Knox
# 11            Boston Blacking Company G.m.b.H.
# 12                   Butler Brothers, G.m.b.H.
# 13      Chesebrough Manufacturing Co. G.m.b.H.
# 14                          Coca-Cola G.m.b.H.
# 15                           Corn Products Co.
# 16                   Deutsche Celotex Vertrieb
# 17  Deutsche Underwood Elliott Fisher G.m.b.H.
# 18                               Durant Motors
# 19               Eagle Oil Company of New York
# 20                                  Elektrolux
# 21                     General Motors G.m.b.H.
# 22       Hobart Gesellschaft, Hamburg, Germany
# 23                              Ingersoll-Rand
# 24     International Harvester Company, m.b.H.
# 25                  Kraft Kaese Werke G.m.b.H.
# 26   Parker Pen Co., G.m.b.H., Berlin, Germany
# 27        Philip Morris & Co. Limited G.m.b.H.
# 28                    Quaker Oats Co. G.m.b.H.
# 29                     Reece Machinery Company
# 30                        S. Oppenheimer & Co.
# 31                 German-American Tobacco Co.
# 32                      Holophane-Gesellschaft
# 33                                 Hupp Motors
# 34                         W. T. Grant Company
#
#                                   US_name  \
# 0             American News Company, Inc.
# 1           Columbia Pictures Corporation
# 2                     O-Cedar Corporation
# 3                       Fairbanks Company
# 4               Gillette Safety Razor Co.
# 5                   Addressograph Company
# 6                         Aeolian Company
# 7                    American Oil Company
# 8                    Bakelite Corporation
# 9           Bausch & Lomb Optical Company
# 10                      Blaw-Knox Company
# 11                Boston Blacking Company
# 12                        Butler Brothers
# 13  Chesebrough Manufacturing Co. (Cons.)
# 14    Coca-Cola International Corporation
# 15         Corn Products Refining Company
# 16                        Celotex Company
# 17       Underwood Elliott Fisher Company
# 18                    Durant Motors, Inc.
# 19                      Eagle Oil Company
# 20          Electrolux Servel Corporation
# 21             General Motors Corporation
# 22           Hobart Manufacturing Company
# 23                 Ingersoll-Rand Company
# 24        International Harvester Company
# 25        Kraft-Phenix Cheese Corporation
# 26                     Parker Pen Company
# 27        Philip Morris & Co., Ltd., Ind.
# 28                    Quaker Oats Company
# 29          Reece Folding Machine Company
# 30             Oppenheimer (S.) & Company
# 31            German-American Tobacco Co.
# 32                Holophane Company, Inc.
# 33             Hupp Motor Car Corporation
# 34                 Grant, (W. T.) Company
#
#                                   Master US firm name HB GmbH class  index  \
# 0                         American News Company, Inc.           USC     53
# 1                             Columbia Pictures Corp.           USC    428
# 2                                 O-Cedar Corporation           USC   1810
# 3                               The Fairbanks Company           USO    710
# 4                       Gillette Safety Rasor Company           USO    887
# 5                Addressograph-Multigraph Corporation           USO      9
# 6                                     Aeolian Company           USO     14
# 7                                American Oil Company           USO     53
# 8                                      Bakelite Corp.           USO    130
# 9                           Bausch & Lomb Optical Co.           USO    171
# 10                                      Blaw-Knox Co.           USO    271
# 11                  United Shoe Machinery Corporation           USO    300
# 12                                    Butler Brothers           USO    368
# 13         Chesebrough Manufacturing Co. Consolidated           USO    412
# 14  The Coca-Cola Company (101 W. 10th Street Wilm...           USO    423
# 15                     Corn Products Refining Company           USO    439
# 16                                        Celotex Co.           USO    496
# 17                   Underwood Elliott Fisher Company           USO    528
# 18                                Durant Motors, Inc.           USO    588
# 19                                  Eagle Oil Company           USO    590
# 20                                       Servel, Inc.           USO    643
# 21   General Motors Corporation (Overseas Operations)           USO    836
# 22                   The Hobart Manufacturing Company           USO   1140
# 23                             Ingersoll-Rand Company           USO   1221
# 24                    International Harvester Company           USO   1227
# 25                               Kraft Cheese Company           USO   1394
# 26                                     Parker Pen Co.           USO   1867
# 27                     Philip Morris & Co. Ltd., Inc.           USO   1696
# 28                                    Quaker Oats Co.           USO   1946
# 29  The International Button Hole Sewing Machine C...           USO   1972
# 30                         Oppenheimer (S.) & Company           USO   1827
# 31                        German-American Tobacco Co.           USO    844
# 32                            Holophane Company, Inc.          USOP   1160
# 33                         Hupp Motor Car Corporation          USOP   1190
# 34                             Grant, (W. T.) Company          USOP    916
#
#     page column                                           location  \
# 0     43  right                        Hamburg, Kl. Reichenstr. 21
# 1    231   left                          Berlin, Charlottenstr. 96
# 2    922   left    Berlin-Borsigwalde, Charlottenburger Str. 15-26
# 3    372   left                                   Hamburg, Brook 1
# 4    460  right                             Hamburg, Spitalstr. 10
# 5     21  right                         Berlin S 24, Ritterstr. 99
# 6     24   left                         Berlin W 10, Lützowufer 17
# 7     43  right                Hamburg, Billwärder Steindamm 14/19
# 8     82   left                         Berlin W 35, Lützowstr. 32
# 9    102  right                 Frankfurt a. M., Schillerstraße 30
# 10   152  right                            Düsseldorf, Sternstr. 9
# 11   167   left                                          Oberursel
# 12   201   left                               Sonneberg, Thüringen
# 13   223   left                  Berlin SO 16, Köpenicker Str. 127
# 14   228  right                                              Essen
# 15   236  right                     Hamburg, Spaldingstraße 216/18
# 16   265   left                                            Potsdam
# 17   281   left                                             Berlin
# 18   311   left                              Berlin W 9, Voßstr. 7
# 19   312   left                           Hamburg, Kirchenallee 25
# 20   338  right  Berlin-Tempelhof, Oberlandstr. 36. Zweign. Danzig
# 21   435   left  Berlin-Borsigwalde, Charlottenburger Straße 65—89
# 22   587  right                                            Hamburg
# 23   627  right                                    Frankfurt a. M.
# 24   630  right  Neuß. Zweign. Berlin, Breslau, Hamburg, Königs...
# 25   714   left                               Hamburg, Esplanade 6
# 26   950  right                       Berlin W 8, Taubenstr. 46 IV
# 27   865   left                      Berlin SW 11, Anhaltstraße 14
# 28   990   left                       Elsen, Amtsger. Grevenbroich
# 29  1003   left                                    Frankfurt a. M.
# 30   930  right                      Hamburg, Catharinenkirchhof 2
# 31   439   left                         Berlin W 10, Lützowufer 17
# 32   597   left               Berlin SW 68, Alte Jakobstraße 20/22
# 33   612   left                                            Hamburg
# 34   475   left                        Berlin SW 68, Ritterstr. 73
#
#           date        capital  \
# 0       9.8.22         RM 600
# 1    14. 5. 20         RM 600
# 2         None     RM 800 000
# 3     30.12.19        RM 5000
# 4    26. 3. 08      RM 62 500
# 5      28.3.28      RM 700000
# 6     5. 6. 07     RM 500 000
# 7       6.3.20         RM 500
# 8    25. 5. 10    RM 1100 000
# 9      30.7.02     RM 100,000
# 10      6.3.30     RM 100,000
# 11    23.12.03     RM 240 000
# 12     22.7.09     RM 154 000
# 13     31.8.16      RM 20 000
# 14     24.5.30     RM 300,000
# 15     14.3.05   RM 1,500,000
# 16      8.7.07      RM 150000
# 17    7. 9. 31     RM 100 000
# 18   15. 5. 28     RM 300 000
# 19    5. 6. 09     RM 100 000
# 20     10.7.25     RM 250,000
# 21      6.2.25    RM 1000 000
# 22      7.3.30     RM 200 000
# 23     2.11.29     RM 150 000
# 24  30. 12. 08  RM 12 000 000
# 25   28. 4. 27      RM 20 000
# 26   25. 1. 30     EM 250 000
# 27   29. 3. 28      RM 20 000
# 28  29. 12. 06      RM 60 000
# 29    9. 9. 30      RM 20 000
# 30   27. 8. 20      RM 10 000
# 31   27. 5. 31      RM 20 000
# 32     16.5.11      RM 20,000
# 33   10. 6. 29      RM 20 000
# 34     29.4.26      RM 20 000
#
#                                              business  \
# 0      Herausgabe einer Zeitung in englischer Sprache
# 1                             Filmschauspiel, Kostüme
# 2   Fabrikation und Vertrieb von O-Cedar-Fabrikate...
# 3   Vertretung der The Fairbanks Company (Europe) ...
# 4   Gewerbliche und fabrikatorische Ausbeutung u. ...
# 5   Vertrieb von Organisationsmaschinen u. Büroart...
# 6      Herstellung und Vertrieb von Musikinstrumenten
# 7                                  Friedrich Bachmann
# 8   Verwertung von Patenten von Kondensationsprodu...
# 9   Fabrikation und Vertrieb von optischen Instrum...
# 10  Herstellung, Vertrieb u. Errichtung von Maschi...
# 11  Herstellung und Vertrieb von Tinten, Farben un...
# 12        Export von Waren aller Art nach Nordamerika
# 13  Vertrieb von amerikanischen Spezialitäten der ...
# 14  Herstellung von und Handel mit alkoholfreien G...
# 15                         Vertrieb von Maisprodukten
# 16  Vertrieb von Isolier- und Bauplatten, insbeson...
# 17  Handel mit Schreib- und Büromaschinen aller Ar...
# 18  Herstellung und Vertrieb von Kraftfahrzeugen u...
# 19        Fabrikation u. Vertrieb von Gelen u. Fetten
# 20   Vertrieb von Elektrolux-Apparaten (Staubsaugern)
# 21                        Fabrikation von Automobilen
# 22  Vertrieb von Hobart-Maschinen für die Zubereit...
# 23  Erzeugung, Reparatur u. Handel von Preßluftmas...
# 24  Herstellung und Vertrieb von Maschinen, insbes...
# 25  Handel mit Produkten der Kraft Cheese Company ...
# 26  Import u. Vertrieb der Erzeugnisse der Akt.-Ge...
# 27  Herstellung u. Vertrieb von Tabakerzeugnissen ...
# 28  Handel mit Bodenfrüchten, Herstellung von Prod...
# 29  Vertretung der International Button Hobo Sevin...
# 30  Handelsgeschäfte mit Därmen, u. anderen animal...
# 31  Handel mit Tabak und Tabakserzeugnissen aller ...
# 32  Vertrieb der Produkte der Holophane-Gesellscha...
# 33  Verkauf, Lagerung u. Spedition von Beförderung...
# 34  Vertretung überseeischer, insbesondere amerika...
#
#                                               persons  \
# 0      Eugene Deutsch; A. H. Bergmann geb. Thomaschek
# 1                                P. Groß; K. Rellstab
# 2                                    Fr. Howe Packord
# 3                                       H. S. Fainaru
# 4                                C. Ferd. Adderhalden
# 5                 R. I. Grog; CI. E. Thone; A. Porter
# 6                 John Albert Findley; Johannes Hauff
# 7                                  Friedrich Bachmann
# 8                    David Sachs; Dr. phil. Max Weger
# 9                                August Heinrich Lomb
# 10                                         W. Schwier
# 11  Svend Jernvet; Georg D. Pike (Boston); John Ro...
# 12               J. Hornbeck; Schoonmacker; P. Schütt
# 13                           Dir. Maximilian Gethmann
# 14                                       A. H. Staton
# 15                                    E. G. H. Dircks
# 16                            R. Schweizer; A. Hafner
# 17                                        And. Lorant
# 18               Dr. Jul. Dünkelsbühler; W. C. Durant
# 19                  G. F. C. von Krogh; V. A. E. Hüne
# 20  Dir. Dr. E. Müllendorff; A. Melin-Högrell; W. ...
# 21                                      A. J. Wieland
# 22                                         R. H. Wark
# 23                                          J. Bolton
# 24  F. J. Brown; P. O. Pleiß; J. G. Sawall; Th. E....
# 25                             Edw. Hermann Kenworthy
# 26                                      A. E. Zoccola
# 27                 Eugen Koch; G. Alexander Ledingham
# 28                                           E. Noell
# 29              J. Reece; W. M. Finkle; H. Bunkenburg
# 30                          A. W. Kempner; L. C. Stör
# 31                                      F. Wirth jun.
# 32                                          J. Franck
# 33                                          Th. Onken
# 34                                       A. Ostermann
#
#                                                type  in TFR-500  in Moodys 32  \
# 0                                             2 Gf.       False         False
# 1                                             Einl.       False         False
# 2                                          Jed. Gf.       False         False
# 3                                             1 Gf.        True         False
# 4                                          Jed. Gf.       False         False
# 5   Jed. Gf. od. 1 Gf. u. 1 Pk. Sacheinl. RM 391000        True         False
# 6                                    1 Gf. od. 2 Pk       False         False
# 7                                             1 Gf.       False         False
# 8                         2 Gf. oder 1 Gf. u. 1 Pk.       False         False
# 9                                      1 Gf or 1 Pk       False         False
# 10                                            1 Gf.       False         False
# 11                1 Gf. od. je 1 Pk. P.K. Ffm. 2423        True         False
# 12                        1 Gf. od. 2 Pk. od. 1 Pk.        True         False
# 13                                            1 Gf.        True         False
# 14                                            1 Gf.        True         False
# 15                                  1 Gf. od. 2 Pk.       False         False
# 16                                               R.       False         False
# 17                                         Jed. Gf.        True         False
# 18                                         Jed. Gf.       False         False
# 19                                         Jed. Gf.       False         False
# 20                         2 Gf. od. 1 Gf. u. 1 Pk.       False         False
# 21                                          Der Gf.        True         False
# 22                                      1 od. 2 Gf.       False         False
# 23                                      1 od. 2 Gf.       False         False
# 24                                         Jed. Gf.        True          True
# 25                                            1 Gf.        True         False
# 26                                             1 Gf       False          True
# 27                                            1 Gf.        True         False
# 28                                            1 Gf.        True         False
# 29                 Gf. R. u. F. allein, sonst 2 Gf.        True          True
# 30                                         Jed. Gf.       False         False
# 31                                      1 od. 2 Gf.       False         False
# 32                                          Der Gf.       False         False
# 33                                             None       False         False
# 34                                      1 od. 2 Gf.       False         False
#
#     in Moodys 34  in Tenenbaum  IDed in HB GmbH _merge
# 0          False         False             True   both
# 1          False         False             True   both
# 2          False         False             True   both
# 3          False         False             True   both
# 4          False         False             True   both
# 5          False          True             True   both
# 6          False         False             True   both
# 7          False         False             True   both
# 8           True         False             True   both
# 9          False         False             True   both
# 10         False         False             True   both
# 11         False         False             True   both
# 12         False         False             True   both
# 13         False         False             True   both
# 14         False          True             True   both
# 15         False         False             True   both
# 16         False         False             True   both
# 17         False         False             True   both
# 18         False         False             True   both
# 19         False         False             True   both
# 20         False         False             True   both
# 21         False         False             True   both
# 22         False         False             True   both
# 23         False         False             True   both
# 24          True          True             True   both
# 25         False          True             True   both
# 26         False         False             True   both
# 27         False         False             True   both
# 28         False         False             True   both
# 29         False         False             True   both
# 30         False         False             True   both
# 31         False         False             True   both
# 32         False         False             True   both
# 33         False         False             True   both
# 34         False         False             True   both

# %%
gmbh_in_hb = pd.concat([fuzzy_searched_merged_hb_gmbh, hb_gmbh_merged_back_and_dummies]).drop(columns=['level_0', 'fuzzy_score', 'match_is_good'])
gmbh_in_hb.to_csv('output/all_searched_in_hb_gmbh.csv')

# %%
gmbh_in_hb
# Out:
#                      Master US firm name  \
# 0      Standard Oil Company (New Jersey)
# 1   Edward G. Budd Manufacturing Company
# 2    The ARMCO International Corporation
# 3       Underwood Elliott Fisher Company
# 4          The Atlantic Refining Company
# ..                                   ...
# 30            Oppenheimer (S.) & Company
# 31           German-American Tobacco Co.
# 32               Holophane Company, Inc.
# 33            Hupp Motor Car Corporation
# 34                Grant, (W. T.) Company
#
#                               Master German firm name  in TFR-500  \
# 0   "Gluckauf" Deutsche Oel Gesellschaft Hersfeld ...        True
# 1               A. B. P. Gefolgschoftsheime, G.m.b.H.        True
# 2                                ARMCO Eisen G.m.b.H.        True
# 3                       Adrema Maschinenebau G.m.b.H.        True
# 4              Allgemeine Oel-Handels, GmbH. (Oelhag)        True
# ..                                                ...         ...
# 30                               S. Oppenheimer & Co.       False
# 31                        German-American Tobacco Co.       False
# 32                             Holophane-Gesellschaft       False
# 33                                        Hupp Motors       False
# 34                                W. T. Grant Company       False
#
#     in Moodys 32  in Moodys 34  in Tenenbaum  IDed in HB GmbH  \
# 0          False         False         False            False
# 1          False         False         False            False
# 2          False         False          True            False
# 3          False         False         False            False
# 4          False          True          True            False
# ..           ...           ...           ...              ...
# 30         False         False         False             True
# 31         False         False         False             True
# 32         False         False         False             True
# 33         False         False         False             True
# 34         False         False         False             True
#
#                               firm_name  searched   index  ...  column  \
# 0                                   NaN       1.0     NaN  ...     NaN
# 1                                   NaN       1.0     NaN  ...     NaN
# 2                                   NaN       1.0     NaN  ...     NaN
# 3    „Adrema“ Maschinenbau-Gesellschaft       1.0    12.0  ...    left
# 4   Allgemeine Oel-Handels-Gesellschaft       1.0    38.0  ...    left
# ..                                  ...       ...     ...  ...     ...
# 30                 S. Oppenheimer & Co.       NaN  1827.0  ...   right
# 31      German American Tobacco Company       NaN   844.0  ...    left
# 32               Holophane-Gesellschaft       NaN  1160.0  ...    left
# 33                          Hupp Motors       NaN  1190.0  ...    left
# 34                  W. T. Grant Company       NaN   916.0  ...    left
#
#                                    location       date       capital  \
# 0                                       NaN        NaN           NaN
# 1                                       NaN        NaN           NaN
# 2                                       NaN        NaN           NaN
# 3   Berlin-Charlottenburg, Alt-Moabit 62/63   2. 4. 13   RM 1000 000
# 4                     Hamburg, Mittelweg 38  8. 12. 20  RM 9 000 000
# ..                                      ...        ...           ...
# 30            Hamburg, Catharinenkirchhof 2  27. 8. 20     RM 10 000
# 31               Berlin W 10, Lützowufer 17  27. 5. 31     RM 20 000
# 32     Berlin SW 68, Alte Jakobstraße 20/22    16.5.11     RM 20,000
# 33                                  Hamburg  10. 6. 29     RM 20 000
# 34              Berlin SW 68, Ritterstr. 73    29.4.26     RM 20 000
#
#                                              business  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                Maschinenfabrikation
# 4               Handel mit Gelen und verwandten Waren
# ..                                                ...
# 30  Handelsgeschäfte mit Därmen, u. anderen animal...
# 31  Handel mit Tabak und Tabakserzeugnissen aller ...
# 32  Vertrieb der Produkte der Holophane-Gesellscha...
# 33  Verkauf, Lagerung u. Spedition von Beförderung...
# 34  Vertretung überseeischer, insbesondere amerika...
#
#                       persons                       type HB GmbH class  \
# 0                         NaN                        NaN           NaN
# 1                         NaN                        NaN           NaN
# 2                         NaN                        NaN           NaN
# 3          Julius Goldschmidt             1 Gf. od. 2 Pk           NaN
# 4                Emanuel Rein  2 Gf. od. 1 Gf. od. 2 Pk.           NaN
# ..                        ...                        ...           ...
# 30  A. W. Kempner; L. C. Stör                   Jed. Gf.           USO
# 31              F. Wirth jun.                1 od. 2 Gf.           USO
# 32                  J. Franck                    Der Gf.          USOP
# 33                  Th. Onken                       None          USOP
# 34               A. Ostermann                1 od. 2 Gf.          USOP
#
#                         US_name _merge
# 0                           NaN    NaN
# 1                           NaN    NaN
# 2                           NaN    NaN
# 3                           NaN    NaN
# 4                           NaN    NaN
# ..                          ...    ...
# 30   Oppenheimer (S.) & Company   both
# 31  German-American Tobacco Co.   both
# 32      Holophane Company, Inc.   both
# 33   Hupp Motor Car Corporation   both
# 34       Grant, (W. T.) Company   both
#
# [270 rows x 21 columns]

# %% [markdown]
# #### combining

# %%
all_not_ided_searched = fuzzy_searched_merged_hb_gmbh.copy()
all_not_ided_searched['appears in HB GmbH'] = all_not_ided_searched['firm_name'].notnull()
all_not_ided_searched = all_not_ided_searched[['Master US firm name', 'Master German firm name', 'appears in HB GmbH']]

# %%
gmbh_large_table = tfr500_moodys32_moodys34_tenenbaum_hb_gmbh.merge(all_not_ided_searched, 
                                                 on=['Master US firm name', 'Master German firm name'],
                                                 how='outer')

gmbh_large_table['appears in HB GmbH'] = gmbh_large_table['appears in HB GmbH'].fillna(False)
# Out:
# /var/folders/44/38ww_5ts5z53mxh7j8kt4dt40000gn/T/ipykernel_34248/4129820660.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gmbh_large_table['appears in HB GmbH'] = gmbh_large_table['appears in HB GmbH'].fillna(False)

# %%
gmbh_large_table
# Out:
#                       Master US firm name  \
# 0    Addressograph-Multigraph Corporation
# 1                         Aeolian Company
# 2               American Cyanamid Company
# 3             American News Company, Inc.
# 4        American Nickel Alloy Mfg. Corp.
# ..                                    ...
# 265   Western Electric Export Corporation
# 266         William R. Warner & Co., Inc.
# 267                   Witroth Corporation
# 268                   Witroth Corporation
# 269  Worthington Pump and Machinery Corp.
#
#                                Master German firm name  in TFR-500  \
# 0                    Addressograph-Multigraph G.m.b.H.        True
# 1                                      Aeolian Company       False
# 2                          Farsals-Gesellschaft m.b.H.        True
# 3                                American News Company       False
# 4    Cosmo Montangesellschaft fuer metallurgische I...        True
# ..                                                 ...         ...
# 265                          Western Electric G.m.b.H.        True
# 266                      Warner, W.R. and Co. G.m.b.H.        True
# 267                   Oppelener Lagerhaus Gesellschaft        True
# 268                                        Ostrhederei        True
# 269           Deutsche Worthington Gesellschaft m.b.H.        True
#
#      in Moodys 32  in Moodys 34  in Tenenbaum HB GmbH class  IDed in HB GmbH  \
# 0           False         False          True           USO             True
# 1           False         False         False           USO             True
# 2           False         False         False           NaN            False
# 3           False         False         False           USC             True
# 4           False         False         False           NaN            False
# ..            ...           ...           ...           ...              ...
# 265         False         False         False           NaN            False
# 266         False         False         False           NaN            False
# 267         False         False         False           NaN            False
# 268         False         False         False           NaN            False
# 269          True          True          True           NaN            False
#
#      appears in HB GmbH
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ..                  ...
# 265                True
# 266                True
# 267                True
# 268                True
# 269                True
#
# [270 rows x 9 columns]

# %%
gmbh_in_hb = gmbh_large_table[gmbh_large_table['IDed in HB GmbH']==True]
gmbh_in_hb_counts = gmbh_in_hb.groupby('HB GmbH class').agg(
    **{
    "count": ("in TFR-500", "size"),       # count of all rows
    "in TFR": ("in TFR-500", "sum")          # sum of True values (sin
}).reindex(['USO', 'USC', 'USOP'])

gmbh_in_hb_counts.to_latex('output/table/hb_gbmh_count_TFR.tex')

# %% [markdown]
# ## Search for firms in the large list

# %%
kw = 'Western Electric'
tfr500_moodys32_moodys34_tenenbaum_hb_gmbh[tfr500_moodys32_moodys34_tenenbaum_hb_gmbh['Master German firm name'].str.contains(kw, case=False)]
# Out:
#                      Master US firm name    Master German firm name  \
# 263  Western Electric Export Corporation  Western Electric G.m.b.H.
#
#      in TFR-500  in Moodys 32  in Moodys 34  in Tenenbaum HB GmbH class  \
# 263        True         False         False         False           NaN
#
#      IDed in HB GmbH
# 263            False

# %%
gmbh_large_table
# Out:
#                       Master US firm name  \
# 0    Addressograph-Multigraph Corporation
# 1                         Aeolian Company
# 2               American Cyanamid Company
# 3             American News Company, Inc.
# 4        American Nickel Alloy Mfg. Corp.
# ..                                    ...
# 265   Western Electric Export Corporation
# 266         William R. Warner & Co., Inc.
# 267                   Witroth Corporation
# 268                   Witroth Corporation
# 269  Worthington Pump and Machinery Corp.
#
#                                Master German firm name  in TFR-500  \
# 0                    Addressograph-Multigraph G.m.b.H.        True
# 1                                      Aeolian Company       False
# 2                          Farsals-Gesellschaft m.b.H.        True
# 3                                American News Company       False
# 4    Cosmo Montangesellschaft fuer metallurgische I...        True
# ..                                                 ...         ...
# 265                          Western Electric G.m.b.H.        True
# 266                      Warner, W.R. and Co. G.m.b.H.        True
# 267                   Oppelener Lagerhaus Gesellschaft        True
# 268                                        Ostrhederei        True
# 269           Deutsche Worthington Gesellschaft m.b.H.        True
#
#      in Moodys 32  in Moodys 34  in Tenenbaum HB GmbH class  IDed in HB GmbH  \
# 0           False         False          True           USO             True
# 1           False         False         False           USO             True
# 2           False         False         False           NaN            False
# 3           False         False         False           USC             True
# 4           False         False         False           NaN            False
# ..            ...           ...           ...           ...              ...
# 265         False         False         False           NaN            False
# 266         False         False         False           NaN            False
# 267         False         False         False           NaN            False
# 268         False         False         False           NaN            False
# 269          True          True          True           NaN            False
#
#      appears in HB GmbH
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ..                  ...
# 265                True
# 266                True
# 267                True
# 268                True
# 269                True
#
# [270 rows x 9 columns]

# %%
print('in TFR: ' + str(gmbh_large_table[(gmbh_large_table['in TFR-500'])].shape[0]))
print('in Tenenbaum: ' + str(gmbh_large_table[(gmbh_large_table['in Tenenbaum'])].shape[0]))
print('in TFR or Tenenbaum: ' + str(gmbh_large_table[((gmbh_large_table['in TFR-500']) |
                    (gmbh_large_table['in Tenenbaum']))].shape[0]))
print('---------')
print('in TFR, and present in HB GmbH: ' + str(gmbh_large_table[(gmbh_large_table['in TFR-500']) &
                    (gmbh_large_table['appears in HB GmbH'])].shape[0]))
print('in Tenenbaum, and present in HB GmbH: ' + str(gmbh_large_table[(gmbh_large_table['in Tenenbaum']) &
                    (gmbh_large_table['appears in HB GmbH'])].shape[0]))
print('in TFR or Tenenbaum, and present in HB GmbH: ' + str(gmbh_large_table[((gmbh_large_table['in TFR-500']) |
                    (gmbh_large_table['in Tenenbaum'])) & 
                    (gmbh_large_table['appears in HB GmbH'])].shape[0]))
# Out:
# in TFR: 209
# in Tenenbaum: 59
# in TFR or Tenenbaum: 221
# ---------
# in TFR, and present in HB GmbH: 149
# in Tenenbaum, and present in HB GmbH: 45
# in TFR or Tenenbaum, and present in HB GmbH: 156

# %%
print('IDed in HB GmbH: ' + str(gmbh_large_table[(gmbh_large_table['IDed in HB GmbH'])].shape[0]))
print('IDed in HB GmbH and in TFR: ' + str(gmbh_large_table[(gmbh_large_table['IDed in HB GmbH']) & (gmbh_large_table['in TFR-500'])].shape[0]))
print('IDed in HB GmbH and in Tenenbaum: ' + str(gmbh_large_table[(gmbh_large_table['IDed in HB GmbH']) & (gmbh_large_table['in Tenenbaum'])].shape[0]))
print('IDed HB GmbH and in TFR or Tenenbaum: ' + str(gmbh_large_table[(gmbh_large_table['IDed in HB GmbH']) & ((gmbh_large_table['in TFR-500']) |
                    (gmbh_large_table['in Tenenbaum']))].shape[0]))
# Out:
# IDed in HB GmbH: 35
# IDed in HB GmbH and in TFR: 13
# IDed in HB GmbH and in Tenenbaum: 4
# IDed HB GmbH and in TFR or Tenenbaum: 13

# %%
print('in Moodys 32: ' + str(gmbh_large_table[(gmbh_large_table['in Moodys 32'])].shape[0]))
print('in Moodys 32 and in TFR: ' + str(gmbh_large_table[(gmbh_large_table['in Moodys 32']) & (gmbh_large_table['in TFR-500'])].shape[0]))
print('in Moodys 32 and in Tenenbaum: ' + str(gmbh_large_table[(gmbh_large_table['in Moodys 32']) & (gmbh_large_table['in Tenenbaum'])].shape[0]))
print('in Moodys 32 and in TFR or Tenenbaum: ' + str(gmbh_large_table[(gmbh_large_table['in Moodys 32']) & ((gmbh_large_table['in TFR-500']) |
                    (gmbh_large_table['in Tenenbaum']))].shape[0]))
print('----------------')
print('in Moodys 34: ' + str(gmbh_large_table[(gmbh_large_table['in Moodys 34'])].shape[0]))
print('in Moodys 34 and in TFR: ' + str(gmbh_large_table[(gmbh_large_table['in Moodys 34']) & (gmbh_large_table['in TFR-500'])].shape[0]))
print('in Moodys 34 and in Tenenbaum: ' + str(gmbh_large_table[(gmbh_large_table['in Moodys 34']) & (gmbh_large_table['in Tenenbaum'])].shape[0]))
print('in Moodys 34 and in TFR or Tenenbaum: ' + str(gmbh_large_table[(gmbh_large_table['in Moodys 34']) & ((gmbh_large_table['in TFR-500']) |
                    (gmbh_large_table['in Tenenbaum']))].shape[0]))
print('----------------')
print('in Moodys 32 or 34: ' + str(gmbh_large_table[((gmbh_large_table['in Moodys 32']) | (gmbh_large_table['in Moodys 34']))].shape[0]))
print('in Moodys 32 or 34 and in TFR: ' + str(gmbh_large_table[((gmbh_large_table['in Moodys 32']) | (gmbh_large_table['in Moodys 34']))
                                                                & (gmbh_large_table['in TFR-500'])].shape[0]))
print('in Moodys 32 or 34 and in Tenenbaum: ' + str(gmbh_large_table[((gmbh_large_table['in Moodys 32']) | (gmbh_large_table['in Moodys 34']))
                                                                      & (gmbh_large_table['in Tenenbaum'])].shape[0]))
print('in Moodys 32 or 34 and in TFR or Tenenbaum: ' + str(gmbh_large_table[((gmbh_large_table['in Moodys 32']) | (gmbh_large_table['in Moodys 34']))
                                                                             & ((gmbh_large_table['in TFR-500']) | (gmbh_large_table['in Tenenbaum']))].shape[0]))
# Out:
# in Moodys 32: 43
# in Moodys 32 and in TFR: 24
# in Moodys 32 and in Tenenbaum: 15
# in Moodys 32 and in TFR or Tenenbaum: 27
# ----------------
# in Moodys 34: 46
# in Moodys 34 and in TFR: 26
# in Moodys 34 and in Tenenbaum: 19
# in Moodys 34 and in TFR or Tenenbaum: 27
# ----------------
# in Moodys 32 or 34: 64
# in Moodys 32 or 34 and in TFR: 32
# in Moodys 32 or 34 and in Tenenbaum: 23
# in Moodys 32 or 34 and in TFR or Tenenbaum: 35

# %%
all_identified = gmbh_large_table[((gmbh_large_table['in Moodys 32']) | (gmbh_large_table['in Moodys 34'])) | (gmbh_large_table['IDed in HB GmbH'])]

# %%
print('all identified: ' + str(all_identified.shape[0]))
print('all identified and in TFR: ' + str(all_identified[all_identified['in TFR-500']].shape[0]))
print('all identified and in Tenenbaum: ' + str(all_identified[all_identified['in Tenenbaum']].shape[0]))
print('all identified and in TFR or Tenenbaum: ' + str(all_identified[(all_identified['in TFR-500']) | (all_identified['in Tenenbaum'])].shape[0]))
# Out:
# all identified: 95
# all identified and in TFR: 43
# all identified and in Tenenbaum: 26
# all identified and in TFR or Tenenbaum: 46
